# %% [markdown]
# ## OGB (Rule-based) —— BOPTEST Benchmark
#
# 在 Jupyter 中运行 Rule OGB 训练（与 `python methods/rule_ogb/train.py` 等价）。
#
# **依赖：** 需将 BOPTEST_Project 中的 `realkd` 目录复制到 BOPTEST_Benchmark 根目录，或保证 PYTHONPATH 包含 BOPTEST_Project。
#
# **使用前请：** 在终端先 `cd` 到 **BOPTEST_Benchmark** 项目根目录，再执行 `jupyter notebook` 或 `jupyter lab`，然后打开本 notebook。

# %%
import os
import sys

ROOT = os.getcwd()
if not os.path.isfile(os.path.join(ROOT, "config.py")):
    print("当前目录:", ROOT)
    print("请先在终端执行: cd /path/to/BOPTEST_Benchmark")
    print("再执行: jupyter notebook")
    raise SystemError("请在 BOPTEST_Benchmark 根目录下启动 Jupyter")

sys.path.insert(0, ROOT)
os.chdir(ROOT)
print("项目根目录:", ROOT)

# %%
# %run methods/rule_ogb/train.py
