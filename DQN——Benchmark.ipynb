# %% [markdown]
# ## DQN —— BOPTEST Benchmark
#
# 在 Jupyter 中运行 DQN 训练（与 `python methods/dqn/train.py` 等价）。
#
# **使用前请：** 在终端先 `cd` 到 **BOPTEST_Benchmark** 项目根目录，再执行 `jupyter notebook` 或 `jupyter lab`，然后打开本 notebook。

# %%
import os
import sys

ROOT = os.getcwd()
if not os.path.isfile(os.path.join(ROOT, "config.py")):
    print("当前目录:", ROOT)
    print("请先在终端执行: cd /path/to/BOPTEST_Benchmark")
    print("再执行: jupyter notebook")
    raise SystemError("请在 BOPTEST_Benchmark 根目录下启动 Jupyter")

sys.path.insert(0, ROOT)
os.chdir(ROOT)
print("项目根目录:", ROOT)
# Out:
# 项目根目录: /Users/yu/Desktop/BOPTEST_Benchmark

# %%
# %run methods/dqn/train.py
# Out:
# ...
# 🚀 BOPTEST DQN 训练 (Benchmark)
# ...
# [00:35:13] INFO  | ✅ 连接成功
#
# ...
# 📊 Episode 1/300
# ...
# [00:35:13] INFO  | 开始重置环境...
# [00:35:13] INFO  | 选择测试案例: bestest_air
# [00:35:13] INFO  | 尝试选择测试案例 (尝试 1/3)...
# [00:35:21] INFO  | ✅ Test ID: bc042178-a68f-40a9-99e8-41abd73a7e7d
# [00:35:24] INFO  |   → Initialize... (start_time=11059200s)
# [00:35:26] INFO  |   ✓ Initialize 成功
# [00:35:26] INFO  |   ✓ Set step 成功
# [00:35:26] INFO  |   → Advance...
# [00:35:26] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.8°C | 室外=  8.6°C | R=-26.22 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A0:0.03, A10:0.02, A7:0.02] | eps=0.999
#            细分: comfort=-26.22, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 20.5°C | 室外=  8.3°C | R= +4.97 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A0:0.03, A7:0.01, A10:0.01] | eps=0.998
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 16.8°C | 室外=  8.6°C | R=-24.91 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
# ...
