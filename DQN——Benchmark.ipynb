# %% [markdown]
# ## DQN —— BOPTEST Benchmark
#
# 在 Jupyter 中运行 DQN 训练（与 `python methods/dqn/train.py` 等价）。
#
# **使用前请：** 在终端先 `cd` 到 **BOPTEST_Benchmark** 项目根目录，再执行 `jupyter notebook` 或 `jupyter lab`，然后打开本 notebook。

# %%
import os
import sys

ROOT = os.getcwd()
if not os.path.isfile(os.path.join(ROOT, "config.py")):
    print("当前目录:", ROOT)
    print("请先在终端执行: cd /path/to/BOPTEST_Benchmark")
    print("再执行: jupyter notebook")
    raise SystemError("请在 BOPTEST_Benchmark 根目录下启动 Jupyter")

sys.path.insert(0, ROOT)
os.chdir(ROOT)
print("项目根目录:", ROOT)
# Out:
# 项目根目录: /Users/yu/Desktop/BOPTEST_Benchmark

# %%
# %run methods/dqn/train.py
# Out:
# ======================================================================
# 🚀 BOPTEST DQN 训练 (Benchmark)
# ======================================================================
# [00:59:47] INFO  | ✅ 连接成功
#
# ============================================================
# 📊 Episode 1/300
# ============================================================
# [00:59:48] INFO  | 开始重置环境...
# [00:59:48] INFO  | 选择测试案例: bestest_air
# [00:59:48] INFO  | 尝试选择测试案例 (尝试 1/3)...
# [00:59:52] INFO  | ✅ Test ID: 1f5b87bf-a003-4713-8550-5bd7628bea87
# [00:59:55] INFO  |   → Initialize... (start_time=4060800s)
# [00:59:56] INFO  |   ✓ Initialize 成功
# [00:59:56] INFO  |   ✓ Set step 成功
# [00:59:56] INFO  |   → Advance...
# [00:59:56] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.4°C | 室外= -4.5°C | R= +4.95 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.999
#            细分: comfort=+5.00, energy=-0.05, smooth=-0.00
#   Step  20 | 室温= 15.1°C | 室外= -5.0°C | R=-59.89 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A16:0.01] | eps=0.998
#            细分: comfort=-59.89, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 14.8°C | 室外= -5.0°C | R=-60.00 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.998
#            细分: comfort=-67.29, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 15.2°C | 室外= -4.1°C | R=-57.20 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.01, A18:0.01, A2:0.01] | eps=0.997
#            细分: comfort=-57.20, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 15.8°C | 室外= -2.8°C | R=-45.04 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.996
#            细分: comfort=-45.04, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 21.7°C | 室外= -2.3°C | R= +4.97 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A7:0.01] | eps=0.995
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 16.8°C | 室外= -3.0°C | R=-25.72 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A1:0.01, A2:0.01] | eps=0.994
#            细分: comfort=-25.71, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 19.4°C | 室外= -4.3°C | R= -1.01 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.993
#            细分: comfort=-0.98, energy=-0.02, smooth=-0.00
#   Step  90 | 室温= 14.5°C | 室外= -8.7°C | R=-60.00 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.993
#            细分: comfort=-76.87, energy=-0.01, smooth=-0.00
#
# ✅ Episode 1 完成 | 总奖励: -2511.7 | 平均室温: 17.5°C | 舒适区: 21.9% | 能耗: 74.74 kW
#    Epsilon: 0.992 | Buffer: 96/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 2/300
# ============================================================
# [00:59:58] INFO  | 开始重置环境...
# [00:59:58] INFO  |   → Initialize... (start_time=27475200s)
# [00:59:59] INFO  |   ✓ Initialize 成功
# [00:59:59] INFO  |   ✓ Set step 成功
# [00:59:59] INFO  |   → Advance...
# [00:59:59] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 18.6°C | 室外= -5.5°C | R= -4.90 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.991
#            细分: comfort=-4.89, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 15.0°C | 室外= -5.5°C | R=-60.00 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A5:0.01] | eps=0.990
#            细分: comfort=-62.43, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 14.8°C | 室外= -4.5°C | R=-60.00 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A1:0.01] | eps=0.990
#            细分: comfort=-67.50, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 17.3°C | 室外= -0.8°C | R=-17.79 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.989
#            细分: comfort=-17.79, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 24.9°C | 室外=  4.4°C | R= -2.02 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.988
#            细分: comfort=-2.01, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 26.0°C | 室外=  7.8°C | R= -9.53 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.987
#            细分: comfort=-9.53, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 24.0°C | 室外=  2.6°C | R= +5.00 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A5:0.01] | eps=0.986
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 22.4°C | 室外=  0.0°C | R= +4.99 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A18:0.01] | eps=0.985
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 17.5°C | 室外=  0.7°C | R=-15.60 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.985
#            细分: comfort=-15.60, energy=-0.01, smooth=-0.00
#
# ✅ Episode 2 完成 | 总奖励: -1036.9 | 平均室温: 19.9°C | 舒适区: 44.8% | 能耗: 58.37 kW
#    Epsilon: 0.984 | Buffer: 192/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 3/300
# ============================================================
# [01:00:01] INFO  | 开始重置环境...
# [01:00:01] INFO  |   → Initialize... (start_time=18144000s)
# [01:00:02] INFO  |   ✓ Initialize 成功
# [01:00:02] INFO  |   ✓ Set step 成功
# [01:00:02] INFO  |   → Advance...
# [01:00:02] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.9°C | 室外= 17.2°C | R= +4.98 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A1:0.01] | eps=0.983
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 21.2°C | 室外= 14.9°C | R= +4.98 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A19:0.01] | eps=0.982
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 21.3°C | 室外= 18.7°C | R= +4.99 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A1:0.01] | eps=0.982
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.8°C | 室外= 25.0°C | R= +5.00 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.981
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 19.9°C | 室外= 29.9°C | R= -0.03 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.980
#            细分: comfort=-0.02, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 20.2°C | 室外= 30.6°C | R= +4.97 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A18:0.01, A15:0.01] | eps=0.979
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 20.1°C | 室外= 28.1°C | R= +4.97 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.978
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  80 | 室温= 24.1°C | 室外= 24.9°C | R= -0.02 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.977
#            细分: comfort=-0.02, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.5°C | 室外= 24.5°C | R= +5.00 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A2:0.01] | eps=0.977
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 3 完成 | 总奖励: -8.1 | 平均室温: 21.5°C | 舒适区: 60.4% | 能耗: 51.14 kW
#    Epsilon: 0.976 | Buffer: 288/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 4/300
# ============================================================
# [01:00:05] INFO  | 开始重置环境...
# [01:00:05] INFO  |   → Initialize... (start_time=22723200s)
# [01:00:05] INFO  |   ✓ Initialize 成功
# [01:00:05] INFO  |   ✓ Set step 成功
# [01:00:05] INFO  |   → Advance...
# [01:00:05] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 19.9°C | 室外=  8.0°C | R= -0.03 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.975
#            细分: comfort=-0.02, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 20.6°C | 室外=  5.9°C | R= +4.97 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.974
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 16.4°C | 室外=  7.4°C | R=-31.85 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A2:0.01] | eps=0.974
#            细分: comfort=-31.85, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 18.3°C | 室外= 15.2°C | R= -7.09 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A15:0.01] | eps=0.973
#            细分: comfort=-7.08, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.6°C | 室外= 18.0°C | R= -6.36 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A15:0.01] | eps=0.972
#            细分: comfort=-6.36, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 20.9°C | 室外= 19.4°C | R= +4.97 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.971
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 20.9°C | 室外= 18.5°C | R= +4.98 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A19:0.01] | eps=0.970
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 23.1°C | 室外= 13.7°C | R= +5.00 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A1:0.01, A15:0.01] | eps=0.969
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 18.6°C | 室外= 12.6°C | R= -5.20 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.969
#            细分: comfort=-5.19, energy=-0.01, smooth=-0.00
#
# ✅ Episode 4 完成 | 总奖励: -271.5 | 平均室温: 20.8°C | 舒适区: 53.1% | 能耗: 56.29 kW
#    Epsilon: 0.968 | Buffer: 384/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 5/300
# ============================================================
# [01:00:08] INFO  | 开始重置环境...
# [01:00:08] INFO  |   → Initialize... (start_time=18662400s)
# [01:00:09] INFO  |   ✓ Initialize 成功
# [01:00:09] INFO  |   ✓ Set step 成功
# [01:00:09] INFO  |   → Advance...
# [01:00:09] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.8°C | 室外= 14.2°C | R=-24.94 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A19:0.01] | eps=0.967
#            细分: comfort=-24.94, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.5°C | 室外= 14.2°C | R=-29.85 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A0:0.01] | eps=0.966
#            细分: comfort=-29.84, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 17.1°C | 室外= 19.5°C | R=-20.42 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.966
#            细分: comfort=-20.41, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 24.1°C | 室外= 25.1°C | R= -0.04 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.965
#            细分: comfort=-0.04, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 26.0°C | 室外= 29.0°C | R= -9.58 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A7:0.01, A16:0.01] | eps=0.964
#            细分: comfort=-9.58, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 21.9°C | 室外= 30.4°C | R= +4.97 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A16:0.01] | eps=0.963
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 25.9°C | 室外= 28.8°C | R= -9.34 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.962
#            细分: comfort=-9.34, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 24.2°C | 室外= 24.5°C | R= -0.13 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A18:0.01] | eps=0.961
#            细分: comfort=-0.13, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 20.9°C | 室外= 19.1°C | R= +4.99 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A18:0.01] | eps=0.961
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 5 完成 | 总奖励: -260.1 | 平均室温: 21.7°C | 舒适区: 50.0% | 能耗: 47.20 kW
#    Epsilon: 0.960 | Buffer: 480/12000 | 动作数: 23
# [01:00:11] INFO  | 开始重置环境...
# [01:00:11] INFO  |   → Initialize... (start_time=0s)
# [01:00:12] INFO  |   ✓ Initialize 成功
# [01:00:12] INFO  |   ✓ Set step 成功
# [01:00:12] INFO  |   → Advance...
# [01:00:12] INFO  | ✅ 环境重置成功
# [01:00:14] INFO  | 开始重置环境...
# [01:00:14] INFO  |   → Initialize... (start_time=7776000s)
# [01:00:15] INFO  |   ✓ Initialize 成功
# [01:00:15] INFO  |   ✓ Set step 成功
# [01:00:15] INFO  |   → Advance...
# [01:00:15] INFO  | ✅ 环境重置成功
# [01:00:17] INFO  | 开始重置环境...
# [01:00:17] INFO  |   → Initialize... (start_time=15552000s)
# [01:00:17] INFO  |   ✓ Initialize 成功
# [01:00:17] INFO  |   ✓ Set step 成功
# [01:00:17] INFO  |   → Advance...
# [01:00:17] INFO  | ✅ 环境重置成功
# [01:00:19] INFO  | 开始重置环境...
# [01:00:19] INFO  |   → Initialize... (start_time=23328000s)
# [01:00:20] INFO  |   ✓ Initialize 成功
# [01:00:20] INFO  |   ✓ Set step 成功
# [01:00:20] INFO  |   → Advance...
# [01:00:20] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -551.64
# /Users/yu/Desktop/BOPTEST_Benchmark/monitor.py:384: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=7)
# [01:00:23] INFO  | 📊 图表已保存（已覆盖）: data/dqn/training_output/progress.png
#
# ============================================================
# 📊 Episode 6/300
# ============================================================
# [01:00:23] INFO  | 开始重置环境...
# [01:00:23] INFO  |   → Initialize... (start_time=27302400s)
# [01:00:24] INFO  |   ✓ Initialize 成功
# [01:00:24] INFO  |   ✓ Set step 成功
# [01:00:24] INFO  |   → Advance...
# [01:00:24] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.2°C | 室外=  0.6°C | R=-35.72 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A2:0.01] | eps=0.959
#            细分: comfort=-35.71, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 15.7°C | 室外=  1.0°C | R=-45.52 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A19:0.01, A14:0.01] | eps=0.958
#            细分: comfort=-45.52, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 18.8°C | 室外=  1.1°C | R= -3.77 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.958
#            细分: comfort=-3.75, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 19.9°C | 室外=  1.6°C | R= -0.03 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.957
#            细分: comfort=-0.02, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 16.2°C | 室外=  2.2°C | R=-36.06 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A18:0.01, A15:0.01] | eps=0.956
#            细分: comfort=-36.06, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 21.4°C | 室外=  2.2°C | R= +4.97 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A16:0.01] | eps=0.955
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 16.4°C | 室外=  1.8°C | R=-32.27 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A1:0.01, A15:0.01] | eps=0.954
#            细分: comfort=-32.27, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 15.2°C | 室外= -0.0°C | R=-57.44 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.953
#            细分: comfort=-57.44, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 14.9°C | 室外=  0.1°C | R=-60.00 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A1:0.01, A16:0.01] | eps=0.953
#            细分: comfort=-65.17, energy=-0.00, smooth=-0.00
#
# ✅ Episode 6 完成 | 总奖励: -2115.1 | 平均室温: 17.8°C | 舒适区: 26.0% | 能耗: 67.68 kW
#    Epsilon: 0.952 | Buffer: 576/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 7/300
# ============================================================
# [01:00:26] INFO  | 开始重置环境...
# [01:00:26] INFO  |   → Initialize... (start_time=9849600s)
# [01:00:27] INFO  |   ✓ Initialize 成功
# [01:00:27] INFO  |   ✓ Set step 成功
# [01:00:27] INFO  |   → Advance...
# [01:00:27] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.6°C | 室外= 13.9°C | R= +4.97 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A0:0.01] | eps=0.951
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 16.3°C | 室外= 11.6°C | R=-34.24 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A15:0.01] | eps=0.950
#            细分: comfort=-34.23, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 21.3°C | 室外= 15.6°C | R= +4.98 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.950
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 23.5°C | 室外= 20.8°C | R= +5.00 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.949
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 19.9°C | 室外= 23.9°C | R= -0.04 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.948
#            细分: comfort=-0.03, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 21.6°C | 室外= 25.2°C | R= +4.97 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.947
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 25.3°C | 室外= 21.5°C | R= -4.33 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A2:0.02, A15:0.01] | eps=0.946
#            细分: comfort=-4.32, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 18.8°C | 室外= 20.8°C | R= -3.36 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A2:0.01] | eps=0.945
#            细分: comfort=-3.35, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 20.1°C | 室外= 18.6°C | R= +4.99 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.945
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 7 完成 | 总奖励: -303.7 | 平均室温: 21.0°C | 舒适区: 46.9% | 能耗: 49.80 kW
#    Epsilon: 0.944 | Buffer: 672/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 8/300
# ============================================================
# [01:00:29] INFO  | 开始重置环境...
# [01:00:29] INFO  |   → Initialize... (start_time=4060800s)
# [01:00:30] INFO  |   ✓ Initialize 成功
# [01:00:30] INFO  |   ✓ Set step 成功
# [01:00:30] INFO  |   → Advance...
# [01:00:30] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.5°C | 室外= -4.5°C | R= +4.95 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A18:0.01] | eps=0.943
#            细分: comfort=+5.00, energy=-0.05, smooth=-0.00
#   Step  20 | 室温= 18.4°C | 室外= -5.0°C | R= -6.31 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A2:0.01] | eps=0.942
#            细分: comfort=-6.29, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 14.9°C | 室外= -5.0°C | R=-60.00 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.942
#            细分: comfort=-63.97, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 15.5°C | 室外= -4.1°C | R=-51.23 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A11:0.01] | eps=0.941
#            细分: comfort=-51.23, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 19.9°C | 室外= -2.8°C | R= -0.03 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A11:0.01] | eps=0.940
#            细分: comfort=-0.02, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 17.1°C | 室外= -2.3°C | R=-20.35 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A1:0.01] | eps=0.939
#            细分: comfort=-20.35, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 16.3°C | 室外= -3.0°C | R=-33.64 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A7:0.01] | eps=0.938
#            细分: comfort=-33.64, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 15.2°C | 室外= -4.3°C | R=-58.32 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.937
#            细分: comfort=-58.32, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 19.5°C | 室外= -8.7°C | R= -0.57 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A2:0.01] | eps=0.937
#            细分: comfort=-0.53, energy=-0.03, smooth=-0.00
#
# ✅ Episode 8 完成 | 总奖励: -1689.1 | 平均室温: 18.2°C | 舒适区: 24.0% | 能耗: 88.24 kW
#    Epsilon: 0.936 | Buffer: 768/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 9/300
# ============================================================
# [01:00:32] INFO  | 开始重置环境...
# [01:00:32] INFO  |   → Initialize... (start_time=18921600s)
# [01:00:33] INFO  |   ✓ Initialize 成功
# [01:00:33] INFO  |   ✓ Set step 成功
# [01:00:33] INFO  |   → Advance...
# [01:00:33] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.7°C | 室外= 16.1°C | R= +4.97 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A1:0.02, A4:0.01, A16:0.01] | eps=0.935
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 21.7°C | 室外= 16.0°C | R= +4.98 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.934
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 21.6°C | 室外= 13.1°C | R= +4.97 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.934
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  40 | 室温= 22.1°C | 室外= 14.5°C | R= +4.99 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.933
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 18.0°C | 室外= 16.0°C | R= -9.84 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.932
#            细分: comfort=-9.83, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 23.2°C | 室外= 17.6°C | R= +5.00 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.931
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 23.6°C | 室外= 18.6°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A18:0.01] | eps=0.930
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 22.3°C | 室外= 17.6°C | R= +4.99 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A19:0.01] | eps=0.929
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 21.4°C | 室外= 14.5°C | R= +4.99 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A16:0.01] | eps=0.929
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 9 完成 | 总奖励: -144.3 | 平均室温: 20.7°C | 舒适区: 65.6% | 能耗: 43.59 kW
#    Epsilon: 0.928 | Buffer: 864/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 10/300
# ============================================================
# [01:00:35] INFO  | 开始重置环境...
# [01:00:35] INFO  |   → Initialize... (start_time=24192000s)
# [01:00:36] INFO  |   ✓ Initialize 成功
# [01:00:36] INFO  |   ✓ Set step 成功
# [01:00:36] INFO  |   → Advance...
# [01:00:36] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 19.6°C | 室外=  4.6°C | R= -0.38 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.927
#            细分: comfort=-0.37, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 20.3°C | 室外=  4.3°C | R= +4.96 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A18:0.01] | eps=0.926
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#   Step  30 | 室温= 15.7°C | 室外=  3.9°C | R=-45.98 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A12:0.01] | eps=0.926
#            细分: comfort=-45.98, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 20.7°C | 室外=  4.6°C | R= +4.98 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.925
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  50 | 室温= 22.1°C | 室外=  6.4°C | R= +4.98 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A18:0.01, A14:0.01] | eps=0.924
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 16.9°C | 室外=  7.9°C | R=-23.37 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A1:0.00] | eps=0.923
#            细分: comfort=-23.37, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 21.5°C | 室外=  6.8°C | R= +4.98 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.922
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 15.9°C | 室外=  4.8°C | R=-42.69 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A19:0.01] | eps=0.921
#            细分: comfort=-42.69, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 16.1°C | 室外=  3.9°C | R=-37.40 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A0:0.01] | eps=0.921
#            细分: comfort=-37.40, energy=-0.00, smooth=-0.00
#
# ✅ Episode 10 完成 | 总奖励: -1138.9 | 平均室温: 18.8°C | 舒适区: 43.8% | 能耗: 62.37 kW
#    Epsilon: 0.920 | Buffer: 960/12000 | 动作数: 23
# [01:00:38] INFO  | 开始重置环境...
# [01:00:38] INFO  |   → Initialize... (start_time=0s)
# [01:00:39] INFO  |   ✓ Initialize 成功
# [01:00:39] INFO  |   ✓ Set step 成功
# [01:00:39] INFO  |   → Advance...
# [01:00:39] INFO  | ✅ 环境重置成功
# [01:00:41] INFO  | 开始重置环境...
# [01:00:41] INFO  |   → Initialize... (start_time=7776000s)
# [01:00:42] INFO  |   ✓ Initialize 成功
# [01:00:42] INFO  |   ✓ Set step 成功
# [01:00:42] INFO  |   → Advance...
# [01:00:42] INFO  | ✅ 环境重置成功
# [01:00:44] INFO  | 开始重置环境...
# [01:00:44] INFO  |   → Initialize... (start_time=15552000s)
# [01:00:45] INFO  |   ✓ Initialize 成功
# [01:00:45] INFO  |   ✓ Set step 成功
# [01:00:45] INFO  |   → Advance...
# [01:00:45] INFO  | ✅ 环境重置成功
# [01:00:46] INFO  | 开始重置环境...
# [01:00:46] INFO  |   → Initialize... (start_time=23328000s)
# [01:00:47] INFO  |   ✓ Initialize 成功
# [01:00:47] INFO  |   ✓ Set step 成功
# [01:00:47] INFO  |   → Advance...
# [01:00:47] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -512.81
# [01:00:50] INFO  | 📊 图表已保存（已覆盖）: data/dqn/training_output/progress.png
#
# ============================================================
# 📊 Episode 11/300
# ============================================================
# [01:00:50] INFO  | 开始重置环境...
# [01:00:50] INFO  |   → Initialize... (start_time=18662400s)
# [01:00:51] INFO  |   ✓ Initialize 成功
# [01:00:51] INFO  |   ✓ Set step 成功
# [01:00:51] INFO  |   → Advance...
# [01:00:51] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.7°C | 室外= 14.2°C | R=-27.18 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.919
#            细分: comfort=-27.18, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 17.0°C | 室外= 14.2°C | R=-21.98 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A7:0.01] | eps=0.918
#            细分: comfort=-21.98, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.8°C | 室外= 19.5°C | R=-25.57 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A16:0.01] | eps=0.918
#            细分: comfort=-25.56, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.8°C | 室外= 25.1°C | R= +5.00 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.917
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 25.9°C | 室外= 29.0°C | R= -9.31 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.916
#            细分: comfort=-9.30, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 26.3°C | 室外= 30.4°C | R=-13.70 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.915
#            细分: comfort=-13.70, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 25.3°C | 室外= 28.8°C | R= -4.34 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A8:0.01] | eps=0.914
#            细分: comfort=-4.34, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 23.8°C | 室外= 24.5°C | R= +5.00 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.914
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.4°C | 室外= 19.1°C | R= +5.00 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A18:0.01, A5:0.01] | eps=0.913
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 11 完成 | 总奖励: -254.4 | 平均室温: 21.4°C | 舒适区: 56.2% | 能耗: 49.26 kW
#    Epsilon: 0.912 | Buffer: 1056/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 12/300
# ============================================================
# [01:00:53] INFO  | 开始重置环境...
# [01:00:53] INFO  |   → Initialize... (start_time=19008000s)
# [01:00:54] INFO  |   ✓ Initialize 成功
# [01:00:54] INFO  |   ✓ Set step 成功
# [01:00:54] INFO  |   → Advance...
# [01:00:54] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.9°C | 室外= 15.0°C | R=-23.79 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A7:0.01, A19:0.01] | eps=0.911
#            细分: comfort=-23.78, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.9°C | 室外= 15.1°C | R=-24.57 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.911
#            细分: comfort=-24.57, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 21.5°C | 室外= 16.5°C | R= +4.98 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A15:0.01, A16:0.01] | eps=0.910
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 18.2°C | 室外= 20.0°C | R= -8.04 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A18:0.02, A4:0.01] | eps=0.909
#            细分: comfort=-8.03, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 24.8°C | 室外= 21.5°C | R= -1.64 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.908
#            细分: comfort=-1.64, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 20.3°C | 室外= 23.1°C | R= +4.98 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.907
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  70 | 室温= 24.4°C | 室外= 23.8°C | R= -0.35 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.906
#            细分: comfort=-0.35, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 22.9°C | 室外= 19.7°C | R= +5.00 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A1:0.01] | eps=0.906
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 19.3°C | 室外= 17.0°C | R= -1.11 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.905
#            细分: comfort=-1.10, energy=-0.00, smooth=-0.00
#
# ✅ Episode 12 完成 | 总奖励: -144.0 | 平均室温: 21.1°C | 舒适区: 52.1% | 能耗: 42.52 kW
#    Epsilon: 0.904 | Buffer: 1152/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 13/300
# ============================================================
# [01:00:57] INFO  | 开始重置环境...
# [01:00:57] INFO  |   → Initialize... (start_time=17798400s)
# [01:00:58] INFO  |   ✓ Initialize 成功
# [01:00:58] INFO  |   ✓ Set step 成功
# [01:00:58] INFO  |   → Advance...
# [01:00:58] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.0°C | 室外= 19.1°C | R= +4.99 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A14:0.01, A2:0.01] | eps=0.903
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 16.6°C | 室外= 17.9°C | R=-28.78 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A11:0.01] | eps=0.903
#            细分: comfort=-28.78, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 22.1°C | 室外= 24.1°C | R= +4.99 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.902
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 24.5°C | 室外= 31.6°C | R= -0.55 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A0:0.01] | eps=0.901
#            细分: comfort=-0.55, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 21.6°C | 室外= 33.6°C | R= +4.97 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A16:0.01] | eps=0.900
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 25.9°C | 室外= 34.9°C | R= -9.30 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.899
#            细分: comfort=-9.29, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 23.2°C | 室外= 34.1°C | R= +4.98 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A0:0.01] | eps=0.898
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 24.1°C | 室外= 29.2°C | R= -0.03 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A1:0.01] | eps=0.898
#            细分: comfort=-0.02, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.9°C | 室外= 24.6°C | R= +5.00 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.897
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 13 完成 | 总奖励: -129.4 | 平均室温: 21.8°C | 舒适区: 51.0% | 能耗: 50.71 kW
#    Epsilon: 0.896 | Buffer: 1248/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 14/300
# ============================================================
# [01:01:00] INFO  | 开始重置环境...
# [01:01:00] INFO  |   → Initialize... (start_time=20390400s)
# [01:01:01] INFO  |   ✓ Initialize 成功
# [01:01:01] INFO  |   ✓ Set step 成功
# [01:01:01] INFO  |   → Advance...
# [01:01:01] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 17.4°C | 室外= 12.1°C | R=-17.55 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A2:0.01] | eps=0.895
#            细分: comfort=-17.54, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 21.2°C | 室外= 10.5°C | R= +4.97 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.895
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 17.7°C | 室外= 18.2°C | R=-13.10 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.894
#            细分: comfort=-13.10, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 18.9°C | 室外= 25.2°C | R= -3.04 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A16:0.01] | eps=0.893
#            细分: comfort=-3.03, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.2°C | 室外= 29.5°C | R= -3.84 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.892
#            细分: comfort=-3.83, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 27.1°C | 室外= 30.6°C | R=-24.65 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.891
#            细分: comfort=-24.65, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 26.4°C | 室外= 27.8°C | R=-14.35 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A19:0.01] | eps=0.890
#            细分: comfort=-14.35, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 21.7°C | 室外= 20.8°C | R= +4.98 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A15:0.02, A16:0.01] | eps=0.890
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  90 | 室温= 20.9°C | 室外= 18.1°C | R= +4.99 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.889
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 14 完成 | 总奖励: -255.7 | 平均室温: 22.0°C | 舒适区: 47.9% | 能耗: 51.95 kW
#    Epsilon: 0.888 | Buffer: 1344/12000 | 动作数: 22
#
# ============================================================
# 📊 Episode 15/300
# ============================================================
# [01:01:04] INFO  | 开始重置环境...
# [01:01:04] INFO  |   → Initialize... (start_time=18921600s)
# [01:01:05] INFO  |   ✓ Initialize 成功
# [01:01:05] INFO  |   ✓ Set step 成功
# [01:01:05] INFO  |   → Advance...
# [01:01:05] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 17.3°C | 室外= 16.1°C | R=-17.98 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A18:0.01] | eps=0.887
#            细分: comfort=-17.98, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 21.4°C | 室外= 16.0°C | R= +4.98 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A2:0.02] | eps=0.887
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 16.3°C | 室外= 13.1°C | R=-34.27 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.886
#            细分: comfort=-34.26, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 17.3°C | 室外= 14.5°C | R=-18.51 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A2:0.01, A4:0.01, A16:0.01] | eps=0.885
#            细分: comfort=-18.51, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 23.1°C | 室外= 16.0°C | R= +5.00 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.884
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 23.2°C | 室外= 17.6°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.883
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 18.3°C | 室外= 18.6°C | R= -7.35 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.01, A18:0.01, A4:0.01] | eps=0.882
#            细分: comfort=-7.34, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 17.5°C | 室外= 17.6°C | R=-16.20 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.882
#            细分: comfort=-16.20, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 21.7°C | 室外= 14.5°C | R= +4.99 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A11:0.01] | eps=0.881
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 15 完成 | 总奖励: -459.7 | 平均室温: 20.0°C | 舒适区: 52.1% | 能耗: 41.04 kW
#    Epsilon: 0.880 | Buffer: 1440/12000 | 动作数: 23
# [01:01:07] INFO  | 开始重置环境...
# [01:01:07] INFO  |   → Initialize... (start_time=0s)
# [01:01:08] INFO  |   ✓ Initialize 成功
# [01:01:08] INFO  |   ✓ Set step 成功
# [01:01:08] INFO  |   → Advance...
# [01:01:08] INFO  | ✅ 环境重置成功
# [01:01:10] INFO  | 开始重置环境...
# [01:01:10] INFO  |   → Initialize... (start_time=7776000s)
# [01:01:10] INFO  |   ✓ Initialize 成功
# [01:01:10] INFO  |   ✓ Set step 成功
# [01:01:10] INFO  |   → Advance...
# [01:01:10] INFO  | ✅ 环境重置成功
# [01:01:12] INFO  | 开始重置环境...
# [01:01:12] INFO  |   → Initialize... (start_time=15552000s)
# [01:01:13] INFO  |   ✓ Initialize 成功
# [01:01:13] INFO  |   ✓ Set step 成功
# [01:01:13] INFO  |   → Advance...
# [01:01:13] INFO  | ✅ 环境重置成功
# [01:01:15] INFO  | 开始重置环境...
# [01:01:15] INFO  |   → Initialize... (start_time=23328000s)
# [01:01:16] INFO  |   ✓ Initialize 成功
# [01:01:16] INFO  |   ✓ Set step 成功
# [01:01:16] INFO  |   → Advance...
# [01:01:16] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -474.86
# [01:01:18] INFO  | 📊 图表已保存（已覆盖）: data/dqn/training_output/progress.png
#
# ============================================================
# 📊 Episode 16/300
# ============================================================
# [01:01:18] INFO  | 开始重置环境...
# [01:01:18] INFO  |   → Initialize... (start_time=6048000s)
# [01:01:19] INFO  |   ✓ Initialize 成功
# [01:01:19] INFO  |   ✓ Set step 成功
# [01:01:19] INFO  |   → Advance...
# [01:01:19] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.7°C | 室外=  1.1°C | R=-45.78 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.879
#            细分: comfort=-45.77, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 19.8°C | 室外= -0.3°C | R= -0.13 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.879
#            细分: comfort=-0.11, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 20.4°C | 室外=  2.9°C | R= +4.97 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.878
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  40 | 室温= 18.1°C | 室外=  9.6°C | R= -9.09 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A15:0.01, A2:0.01] | eps=0.877
#            细分: comfort=-9.09, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.5°C | 室外= 14.2°C | R= -5.55 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.876
#            细分: comfort=-5.54, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 26.9°C | 室外= 14.3°C | R=-21.43 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A16:0.01] | eps=0.875
#            细分: comfort=-21.42, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 21.1°C | 室外= 10.6°C | R= +4.98 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A15:0.01, A2:0.01] | eps=0.874
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 23.4°C | 室外=  6.9°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A18:0.01, A16:0.01] | eps=0.874
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 22.5°C | 室外=  3.6°C | R= +4.99 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A2:0.01] | eps=0.873
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 16 完成 | 总奖励: -541.5 | 平均室温: 21.2°C | 舒适区: 45.8% | 能耗: 58.09 kW
#    Epsilon: 0.872 | Buffer: 1536/12000 | 动作数: 22
#
# ============================================================
# 📊 Episode 17/300
# ============================================================
# [01:01:22] INFO  | 开始重置环境...
# [01:01:22] INFO  |   → Initialize... (start_time=29376000s)
# [01:01:22] INFO  |   ✓ Initialize 成功
# [01:01:22] INFO  |   ✓ Set step 成功
# [01:01:22] INFO  |   → Advance...
# [01:01:22] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.9°C | 室外= -0.2°C | R=-41.26 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.871
#            细分: comfort=-41.26, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 19.4°C | 室外= -3.6°C | R= -0.92 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.871
#            细分: comfort=-0.89, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 17.6°C | 室外= -6.2°C | R=-14.35 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A18:0.01, A2:0.01] | eps=0.870
#            细分: comfort=-14.33, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 20.1°C | 室外= -7.6°C | R= +4.95 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A2:0.02, A15:0.01] | eps=0.869
#            细分: comfort=+5.00, energy=-0.05, smooth=-0.00
#   Step  50 | 室温= 19.4°C | 室外= -8.4°C | R= -0.82 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.868
#            细分: comfort=-0.80, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 14.8°C | 室外= -9.0°C | R=-60.00 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A15:0.01] | eps=0.867
#            细分: comfort=-67.23, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 17.2°C | 室外=-10.9°C | R=-19.51 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.866
#            细分: comfort=-19.49, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 15.9°C | 室外=-14.4°C | R=-41.37 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.866
#            细分: comfort=-41.35, energy=-0.03, smooth=-0.00
#   Step  90 | 室温= 15.3°C | 室外=-14.8°C | R=-56.35 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A0:0.01] | eps=0.865
#            细分: comfort=-56.32, energy=-0.03, smooth=-0.00
#
# ✅ Episode 17 完成 | 总奖励: -2659.8 | 平均室温: 17.0°C | 舒适区: 8.3% | 能耗: 115.52 kW
#    Epsilon: 0.864 | Buffer: 1632/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 18/300
# ============================================================
# [01:01:25] INFO  | 开始重置环境...
# [01:01:25] INFO  |   → Initialize... (start_time=30153600s)
# [01:01:25] INFO  |   ✓ Initialize 成功
# [01:01:25] INFO  |   ✓ Set step 成功
# [01:01:25] INFO  |   → Advance...
# [01:01:25] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.1°C | 室外= -7.7°C | R= +4.95 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.863
#            细分: comfort=+5.00, energy=-0.05, smooth=-0.00
#   Step  20 | 室温= 14.8°C | 室外= -9.0°C | R=-60.00 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.863
#            细分: comfort=-68.38, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 18.4°C | 室外= -8.0°C | R= -6.10 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A18:0.01] | eps=0.862
#            细分: comfort=-6.07, energy=-0.03, smooth=-0.00
#   Step  40 | 室温= 21.8°C | 室外= -4.1°C | R= +4.98 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A2:0.01] | eps=0.861
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  50 | 室温= 19.3°C | 室外=  0.5°C | R= -1.33 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.860
#            细分: comfort=-1.32, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 20.0°C | 室外=  2.0°C | R= -0.02 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A15:0.01] | eps=0.859
#            细分: comfort=-0.00, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 18.4°C | 室外= -1.8°C | R= -6.05 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A15:0.01] | eps=0.858
#            细分: comfort=-6.04, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 20.4°C | 室外= -5.6°C | R= +4.98 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.858
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  90 | 室温= 16.5°C | 室外= -6.9°C | R=-30.03 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A19:0.01] | eps=0.857
#            细分: comfort=-30.03, energy=-0.00, smooth=-0.00
#
# ✅ Episode 18 完成 | 总奖励: -1254.9 | 平均室温: 18.9°C | 舒适区: 33.3% | 能耗: 72.51 kW
#    Epsilon: 0.856 | Buffer: 1728/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 19/300
# ============================================================
# [01:01:28] INFO  | 开始重置环境...
# [01:01:28] INFO  |   → Initialize... (start_time=5356800s)
# [01:01:29] INFO  |   ✓ Initialize 成功
# [01:01:29] INFO  |   ✓ Set step 成功
# [01:01:29] INFO  |   → Advance...
# [01:01:29] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.7°C | 室外= -0.1°C | R=-47.01 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.855
#            细分: comfort=-47.00, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 19.3°C | 室外=  5.3°C | R= -1.28 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A14:0.01, A16:0.01] | eps=0.855
#            细分: comfort=-1.27, energy=-0.01, smooth=-0.00
#   Step  30 | 室温= 16.6°C | 室外=  7.5°C | R=-28.89 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.854
#            细分: comfort=-28.89, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 19.1°C | 室外= 12.0°C | R= -1.96 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A18:0.01] | eps=0.853
#            细分: comfort=-1.95, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 24.9°C | 室外= 14.3°C | R= -1.90 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.852
# ...
# [01:05:21] INFO  | 开始重置环境...
# [01:05:21] INFO  |   → Initialize... (start_time=16329600s)
# [01:05:22] INFO  |   ✓ Initialize 成功
# [01:05:22] INFO  |   ✓ Set step 成功
# [01:05:22] INFO  |   → Advance...
# [01:05:22] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.6°C | 室外= 16.2°C | R= +4.98 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.496
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 17.6°C | 室外= 16.2°C | R=-14.78 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A15:0.01, A2:0.01] | eps=0.495
#            细分: comfort=-14.77, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 22.2°C | 室外= 21.5°C | R= +4.99 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.494
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 24.0°C | 室外= 28.4°C | R= +4.99 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A2:0.01] | eps=0.493
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.4°C | 室外= 31.4°C | R= -4.78 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.492
#            细分: comfort=-4.77, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 25.0°C | 室外= 32.1°C | R= -2.60 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A0:0.01] | eps=0.492
#            细分: comfort=-2.60, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 25.5°C | 室外= 31.3°C | R= -5.43 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A11:0.01] | eps=0.491
#            细分: comfort=-5.43, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 24.9°C | 室外= 28.4°C | R= -1.91 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A15:0.01] | eps=0.490
#            细分: comfort=-1.91, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.7°C | 室外= 22.5°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A0:0.01] | eps=0.489
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 64 完成 | 总奖励: -172.5 | 平均室温: 22.3°C | 舒适区: 46.9% | 能耗: 43.55 kW
#    Epsilon: 0.489 | Buffer: 6144/12000 | 动作数: 22
#
# ============================================================
# 📊 Episode 65/300
# ============================================================
# [01:05:25] INFO  | 开始重置环境...
# [01:05:25] INFO  |   → Initialize... (start_time=11577600s)
# [01:05:25] INFO  |   ✓ Initialize 成功
# [01:05:25] INFO  |   ✓ Set step 成功
# [01:05:25] INFO  |   → Advance...
# [01:05:25] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.9°C | 室外=  9.6°C | R= +4.97 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.02, A16:0.01] | eps=0.488
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 21.2°C | 室外=  8.5°C | R= +4.97 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.487
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 21.0°C | 室外= 14.5°C | R= +4.98 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A2:0.02] | eps=0.486
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 23.6°C | 室外= 21.0°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A18:0.01] | eps=0.485
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 25.4°C | 室外= 24.6°C | R= -5.12 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A15:0.01] | eps=0.484
#            细分: comfort=-5.12, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 21.3°C | 室外= 26.6°C | R= +4.98 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.02] | eps=0.484
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  70 | 室温= 25.3°C | 室外= 24.7°C | R= -4.55 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A15:0.02, A14:0.01] | eps=0.483
#            细分: comfort=-4.55, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 21.0°C | 室外= 20.7°C | R= +4.99 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A11:0.01] | eps=0.482
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 23.2°C | 室外= 15.8°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A1:0.01] | eps=0.481
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 65 完成 | 总奖励: -212.9 | 平均室温: 21.7°C | 舒适区: 53.1% | 能耗: 43.72 kW
#    Epsilon: 0.481 | Buffer: 6240/12000 | 动作数: 22
# [01:05:28] INFO  | 开始重置环境...
# [01:05:28] INFO  |   → Initialize... (start_time=0s)
# [01:05:28] INFO  |   ✓ Initialize 成功
# [01:05:28] INFO  |   ✓ Set step 成功
# [01:05:28] INFO  |   → Advance...
# [01:05:28] INFO  | ✅ 环境重置成功
# [01:05:30] INFO  | 开始重置环境...
# [01:05:30] INFO  |   → Initialize... (start_time=7776000s)
# [01:05:31] INFO  |   ✓ Initialize 成功
# [01:05:31] INFO  |   ✓ Set step 成功
# [01:05:31] INFO  |   → Advance...
# [01:05:31] INFO  | ✅ 环境重置成功
# [01:05:32] INFO  | 开始重置环境...
# [01:05:32] INFO  |   → Initialize... (start_time=15552000s)
# [01:05:33] INFO  |   ✓ Initialize 成功
# [01:05:33] INFO  |   ✓ Set step 成功
# [01:05:33] INFO  |   → Advance...
# [01:05:33] INFO  | ✅ 环境重置成功
# [01:05:35] INFO  | 开始重置环境...
# [01:05:35] INFO  |   → Initialize... (start_time=23328000s)
# [01:05:35] INFO  |   ✓ Initialize 成功
# [01:05:35] INFO  |   ✓ Set step 成功
# [01:05:35] INFO  |   → Advance...
# [01:05:35] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -487.78
# [01:05:38] INFO  | 📊 图表已保存（已覆盖）: data/dqn/training_output/progress.png
#
# ============================================================
# 📊 Episode 66/300
# ============================================================
# [01:05:38] INFO  | 开始重置环境...
# [01:05:38] INFO  |   → Initialize... (start_time=24537600s)
# [01:05:39] INFO  |   ✓ Initialize 成功
# [01:05:39] INFO  |   ✓ Set step 成功
# [01:05:39] INFO  |   → Advance...
# [01:05:39] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.0°C | 室外=  5.2°C | R=-39.89 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A14:0.01] | eps=0.480
#            细分: comfort=-39.88, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.1°C | 室外=  5.6°C | R=-38.77 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.02, A19:0.01] | eps=0.479
#            细分: comfort=-38.77, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 19.2°C | 室外=  5.5°C | R= -1.68 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A1:0.01, A18:0.01] | eps=0.478
#            细分: comfort=-1.67, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 22.0°C | 室外= 12.3°C | R= +4.98 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A5:0.01] | eps=0.477
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  50 | 室温= 22.8°C | 室外= 15.6°C | R= +5.00 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.476
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 23.9°C | 室外= 16.8°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A15:0.01, A2:0.01] | eps=0.476
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 19.4°C | 室外= 17.8°C | R= -0.83 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.475
#            细分: comfort=-0.83, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 21.9°C | 室外= 10.1°C | R= +4.99 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.01, A15:0.01, A16:0.01] | eps=0.474
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 18.1°C | 室外=  7.4°C | R= -8.94 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.473
#            细分: comfort=-8.93, energy=-0.00, smooth=-0.00
#
# ✅ Episode 66 完成 | 总奖励: -394.3 | 平均室温: 20.2°C | 舒适区: 58.3% | 能耗: 53.32 kW
#    Epsilon: 0.473 | Buffer: 6336/12000 | 动作数: 21
#
# ============================================================
# 📊 Episode 67/300
# ============================================================
# [01:05:41] INFO  | 开始重置环境...
# [01:05:41] INFO  |   → Initialize... (start_time=2246400s)
# [01:05:42] INFO  |   ✓ Initialize 成功
# [01:05:42] INFO  |   ✓ Set step 成功
# [01:05:42] INFO  |   → Advance...
# [01:05:42] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 18.3°C | 室外= -7.0°C | R= -7.31 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A2:0.01] | eps=0.472
#            细分: comfort=-7.29, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 17.7°C | 室外= -6.8°C | R=-13.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A15:0.01] | eps=0.471
#            细分: comfort=-12.98, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 20.0°C | 室外= -4.6°C | R= +4.94 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A15:0.02, A16:0.02, A4:0.02] | eps=0.470
#            细分: comfort=+5.00, energy=-0.06, smooth=-0.00
#   Step  40 | 室温= 22.4°C | 室外=  3.3°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.02, A15:0.01] | eps=0.469
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 21.1°C | 室外=  5.8°C | R= +4.99 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A18:0.01] | eps=0.468
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 18.7°C | 室外=  5.2°C | R= -4.11 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A14:0.01] | eps=0.468
#            细分: comfort=-4.10, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 22.9°C | 室外=  2.9°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A2:0.01, A14:0.01] | eps=0.467
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 16.9°C | 室外= -1.3°C | R=-24.65 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A5:0.01] | eps=0.466
#            细分: comfort=-24.64, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 19.8°C | 室外= -2.7°C | R= -0.12 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A15:0.01, A7:0.01] | eps=0.465
#            细分: comfort=-0.11, energy=-0.01, smooth=-0.00
#
# ✅ Episode 67 完成 | 总奖励: -758.0 | 平均室温: 19.8°C | 舒适区: 45.8% | 能耗: 58.43 kW
#    Epsilon: 0.465 | Buffer: 6432/12000 | 动作数: 19
#
# ============================================================
# 📊 Episode 68/300
# ============================================================
# [01:05:44] INFO  | 开始重置环境...
# [01:05:44] INFO  |   → Initialize... (start_time=16416000s)
# [01:05:45] INFO  |   ✓ Initialize 成功
# [01:05:45] INFO  |   ✓ Set step 成功
# [01:05:45] INFO  |   → Advance...
# [01:05:45] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 22.1°C | 室外= 20.7°C | R= +4.98 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A16:0.01] | eps=0.464
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 18.0°C | 室外= 18.4°C | R= -9.63 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A0:0.01] | eps=0.463
#            细分: comfort=-9.63, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 22.4°C | 室外= 24.3°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.462
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 25.1°C | 室外= 30.4°C | R= -3.03 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A15:0.02, A16:0.01] | eps=0.461
#            细分: comfort=-3.03, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 26.5°C | 室外= 33.9°C | R=-15.32 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A15:0.01] | eps=0.460
#            细分: comfort=-15.31, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 26.6°C | 室外= 31.1°C | R=-16.35 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.02, A2:0.01] | eps=0.460
#            细分: comfort=-16.35, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 25.5°C | 室外= 25.7°C | R= -5.55 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A18:0.01] | eps=0.459
#            细分: comfort=-5.55, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 24.7°C | 室外= 24.8°C | R= -1.16 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.458
#            细分: comfort=-1.15, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 19.1°C | 室外= 21.3°C | R= -2.15 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A18:0.01] | eps=0.457
#            细分: comfort=-2.14, energy=-0.01, smooth=-0.00
#
# ✅ Episode 68 完成 | 总奖励: -6.4 | 平均室温: 22.9°C | 舒适区: 53.1% | 能耗: 41.38 kW
#    Epsilon: 0.457 | Buffer: 6528/12000 | 动作数: 22
#
# ============================================================
# 📊 Episode 69/300
# ============================================================
# [01:05:47] INFO  | 开始重置环境...
# [01:05:47] INFO  |   → Initialize... (start_time=29203200s)
# [01:05:48] INFO  |   ✓ Initialize 成功
# [01:05:48] INFO  |   ✓ Set step 成功
# [01:05:48] INFO  |   → Advance...
# [01:05:48] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.7°C | 室外= -7.0°C | R=-45.50 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A18:0.02, A16:0.02] | eps=0.456
#            细分: comfort=-45.50, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 19.2°C | 室外= -7.1°C | R= -1.62 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A2:0.01, A16:0.01] | eps=0.455
#            细分: comfort=-1.59, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 14.7°C | 室外= -6.1°C | R=-60.00 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A14:0.01] | eps=0.454
#            细分: comfort=-70.27, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 17.2°C | 室外= -0.6°C | R=-19.57 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A2:0.02, A16:0.01] | eps=0.453
#            细分: comfort=-19.56, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 19.5°C | 室外=  6.9°C | R= -0.77 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.452
#            细分: comfort=-0.76, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 24.7°C | 室外=  9.4°C | R= -1.34 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A2:0.01] | eps=0.452
#            细分: comfort=-1.33, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 24.1°C | 室外=  4.1°C | R= -0.02 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A14:0.01] | eps=0.451
#            细分: comfort=-0.02, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 22.2°C | 室外=  3.9°C | R= +4.99 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.02, A15:0.01] | eps=0.450
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 20.7°C | 室外= -0.8°C | R= +4.98 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A4:0.02, A16:0.01, A1:0.01] | eps=0.449
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#
# ✅ Episode 69 完成 | 总奖励: -504.1 | 平均室温: 20.4°C | 舒适区: 43.8% | 能耗: 66.00 kW
#    Epsilon: 0.449 | Buffer: 6624/12000 | 动作数: 19
#
# ============================================================
# 📊 Episode 70/300
# ============================================================
# [01:05:50] INFO  | 开始重置环境...
# [01:05:50] INFO  |   → Initialize... (start_time=9417600s)
# [01:05:51] INFO  |   ✓ Initialize 成功
# [01:05:51] INFO  |   ✓ Set step 成功
# [01:05:51] INFO  |   → Advance...
# [01:05:51] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.1°C | 室外=  4.7°C | R=-37.62 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A4:0.01, A15:0.01] | eps=0.448
#            细分: comfort=-37.62, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.2°C | 室外=  3.6°C | R=-36.09 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A4:0.03, A16:0.01, A18:0.01] | eps=0.447
#            细分: comfort=-36.09, energy=-0.00, smooth=-0.00
