# %% [markdown]
# ## DQN —— BOPTEST Benchmark
#
# 在 Jupyter 中运行 DQN 训练（与 `python methods/dqn/train.py` 等价）。
#
# **使用前请：** 在终端先 `cd` 到 **BOPTEST_Benchmark** 项目根目录，再执行 `jupyter notebook` 或 `jupyter lab`，然后打开本 notebook。

# %%
import os
import sys

ROOT = os.getcwd()
if not os.path.isfile(os.path.join(ROOT, "config.py")):
    print("当前目录:", ROOT)
    print("请先在终端执行: cd /path/to/BOPTEST_Benchmark")
    print("再执行: jupyter notebook")
    raise SystemError("请在 BOPTEST_Benchmark 根目录下启动 Jupyter")

sys.path.insert(0, ROOT)
os.chdir(ROOT)
print("项目根目录:", ROOT)
# Out:
# 项目根目录: /Users/yu/Desktop/BOPTEST_Benchmark

# %%
# %run methods/dqn/train.py
# Out:
# ======================================================================
# 🚀 BOPTEST DQN 训练 (Benchmark)
# ======================================================================
# [00:21:58] INFO  | ✅ 连接成功
#
# ============================================================
# 📊 Episode 1/300
# ============================================================
# [00:21:58] INFO  | 开始重置环境...
# [00:21:58] INFO  | 选择测试案例: bestest_air
# [00:21:58] INFO  | 尝试选择测试案例 (尝试 1/3)...
# [00:22:01] INFO  | ✅ Test ID: 30a18696-8548-42c7-90d9-9851eb83701a
# [00:22:04] INFO  |   → Initialize... (start_time=4579200s)
# [00:22:05] INFO  |   ✓ Initialize 成功
# [00:22:05] INFO  |   ✓ Set step 成功
# [00:22:05] INFO  |   → Advance...
# [00:22:05] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.2°C | 室外= -8.9°C | R=-57.03 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A6:0.01] | eps=0.999
#            细分: comfort=-57.03, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 14.8°C | 室外= -7.5°C | R=-60.00 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A20:0.01] | eps=0.998
#            细分: comfort=-67.59, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 14.8°C | 室外= -4.7°C | R=-60.00 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A9:0.01] | eps=0.998
#            细分: comfort=-68.73, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 20.4°C | 室外=  1.4°C | R= +4.97 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A12:0.01, A3:0.01, A18:0.01] | eps=0.997
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  50 | 室温= 20.7°C | 室外=  5.6°C | R= +4.98 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A16:0.01, A18:0.01] | eps=0.996
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 22.0°C | 室外=  8.1°C | R= +4.99 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A9:0.01] | eps=0.995
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 21.9°C | 室外=  7.5°C | R= +4.99 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A20:0.01] | eps=0.994
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 16.0°C | 室外=  1.4°C | R=-40.59 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A19:0.01] | eps=0.993
#            细分: comfort=-40.59, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 15.5°C | 室外= -0.4°C | R=-50.67 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A20:0.01] | eps=0.993
#            细分: comfort=-50.67, energy=-0.00, smooth=-0.00
#
# ✅ Episode 1 完成 | 总奖励: -1619.3 | 平均室温: 18.4°C | 舒适区: 34.4% | 能耗: 72.95 kW
#    Epsilon: 0.992 | Buffer: 96/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 2/300
# ============================================================
# [00:22:07] INFO  | 开始重置环境...
# [00:22:07] INFO  |   → Initialize... (start_time=25315200s)
# [00:22:08] INFO  |   ✓ Initialize 成功
# [00:22:08] INFO  |   ✓ Set step 成功
# [00:22:08] INFO  |   → Advance...
# [00:22:08] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.0°C | 室外=  5.5°C | R= -0.01 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.991
#            细分: comfort=-0.00, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 20.5°C | 室外=  4.8°C | R= +4.97 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A12:0.01] | eps=0.990
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 20.5°C | 室外=  5.4°C | R= +4.97 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A20:0.01] | eps=0.990
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  40 | 室温= 23.4°C | 室外= 14.9°C | R= +5.00 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.989
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 23.7°C | 室外= 22.9°C | R= +4.98 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.988
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 23.2°C | 室外= 24.5°C | R= +4.97 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A1:0.01] | eps=0.987
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 25.4°C | 室外= 20.2°C | R= -4.79 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.986
#            细分: comfort=-4.78, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 24.0°C | 室外= 16.9°C | R= -0.01 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A9:0.01] | eps=0.985
#            细分: comfort=-0.01, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.7°C | 室外= 16.0°C | R= +5.00 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A16:0.01] | eps=0.985
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 2 完成 | 总奖励: -312.7 | 平均室温: 21.9°C | 舒适区: 55.2% | 能耗: 64.31 kW
#    Epsilon: 0.984 | Buffer: 192/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 3/300
# ============================================================
# [00:22:10] INFO  | 开始重置环境...
# [00:22:10] INFO  |   → Initialize... (start_time=23587200s)
# [00:22:11] INFO  |   ✓ Initialize 成功
# [00:22:11] INFO  |   ✓ Set step 成功
# [00:22:11] INFO  |   → Advance...
# [00:22:11] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.4°C | 室外=  2.1°C | R= +4.97 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A6:0.01, A18:0.01] | eps=0.983
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 15.5°C | 室外=  0.9°C | R=-50.87 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A17:0.01] | eps=0.982
#            细分: comfort=-50.87, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 20.7°C | 室外=  0.6°C | R= +4.96 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A9:0.01, A6:0.01] | eps=0.982
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#   Step  40 | 室温= 18.3°C | 室外=  6.5°C | R= -7.31 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A20:0.01, A9:0.01] | eps=0.981
#            细分: comfort=-7.31, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 19.9°C | 室外=  9.2°C | R= -0.03 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A13:0.01] | eps=0.980
#            细分: comfort=-0.03, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 22.6°C | 室外=  5.6°C | R= +4.99 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A9:0.01] | eps=0.979
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 21.8°C | 室外=  3.3°C | R= +4.99 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A8:0.01] | eps=0.978
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 16.3°C | 室外=  2.6°C | R=-33.62 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A12:0.01] | eps=0.977
#            细分: comfort=-33.62, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 19.5°C | 室外=  1.1°C | R= -0.70 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A13:0.01] | eps=0.977
#            细分: comfort=-0.69, energy=-0.01, smooth=-0.00
#
# ✅ Episode 3 完成 | 总奖励: -902.6 | 平均室温: 19.4°C | 舒适区: 47.9% | 能耗: 53.54 kW
#    Epsilon: 0.976 | Buffer: 288/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 4/300
# ============================================================
# [00:22:13] INFO  | 开始重置环境...
# [00:22:13] INFO  |   → Initialize... (start_time=28598400s)
# [00:22:14] INFO  |   ✓ Initialize 成功
# [00:22:14] INFO  |   ✓ Set step 成功
# [00:22:14] INFO  |   → Advance...
# [00:22:14] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.0°C | 室外= -3.1°C | R= -0.02 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A17:0.02] | eps=0.975
#            细分: comfort=-0.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 18.1°C | 室外= -3.2°C | R= -9.50 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A20:0.01] | eps=0.974
#            细分: comfort=-9.49, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 14.9°C | 室外= -3.2°C | R=-60.00 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A7:0.01] | eps=0.974
#            细分: comfort=-64.71, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 22.3°C | 室外=  1.8°C | R= +4.99 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A21:0.01] | eps=0.973
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 22.5°C | 室外=  9.6°C | R= +4.98 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.972
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 23.7°C | 室外= 11.4°C | R= +4.98 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A17:0.01] | eps=0.971
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  70 | 室温= 19.4°C | 室外=  6.5°C | R= -1.01 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A16:0.01] | eps=0.970
#            细分: comfort=-0.99, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 19.3°C | 室外=  3.2°C | R= -1.35 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A16:0.01] | eps=0.969
#            细分: comfort=-1.34, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 17.7°C | 室外=  6.1°C | R=-13.53 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.969
#            细分: comfort=-13.52, energy=-0.01, smooth=-0.00
#
# ✅ Episode 4 完成 | 总奖励: -872.4 | 平均室温: 19.8°C | 舒适区: 40.6% | 能耗: 64.13 kW
#    Epsilon: 0.968 | Buffer: 384/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 5/300
# ============================================================
# [00:22:17] INFO  | 开始重置环境...
# [00:22:17] INFO  |   → Initialize... (start_time=11836800s)
# [00:22:17] INFO  |   ✓ Initialize 成功
# [00:22:17] INFO  |   ✓ Set step 成功
# [00:22:17] INFO  |   → Advance...
# [00:22:17] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.7°C | 室外= 14.0°C | R= +4.97 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A20:0.01] | eps=0.967
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 21.4°C | 室外= 12.1°C | R= +4.97 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A9:0.01] | eps=0.966
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  30 | 室温= 16.6°C | 室外= 16.9°C | R=-29.35 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A16:0.01] | eps=0.966
#            细分: comfort=-29.35, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 18.2°C | 室外= 22.5°C | R= -7.86 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A6:0.01] | eps=0.965
#            细分: comfort=-7.85, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 19.5°C | 室外= 25.3°C | R= -0.62 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A12:0.01] | eps=0.964
#            细分: comfort=-0.61, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 24.4°C | 室外= 26.0°C | R= -0.39 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A6:0.01, A13:0.01] | eps=0.963
#            细分: comfort=-0.38, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 24.6°C | 室外= 24.2°C | R= -0.87 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A12:0.01, A3:0.01] | eps=0.962
#            细分: comfort=-0.86, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 18.7°C | 室外= 19.7°C | R= -4.42 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A13:0.01] | eps=0.961
#            细分: comfort=-4.41, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 18.1°C | 室外= 17.3°C | R= -9.02 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A16:0.01, A18:0.01] | eps=0.961
#            细分: comfort=-9.01, energy=-0.01, smooth=-0.00
#
# ✅ Episode 5 完成 | 总奖励: -265.8 | 平均室温: 20.9°C | 舒适区: 42.7% | 能耗: 49.76 kW
#    Epsilon: 0.960 | Buffer: 480/12000 | 动作数: 24
# [00:22:20] INFO  | 开始重置环境...
# [00:22:20] INFO  |   → Initialize... (start_time=0s)
# [00:22:21] INFO  |   ✓ Initialize 成功
# [00:22:21] INFO  |   ✓ Set step 成功
# [00:22:21] INFO  |   → Advance...
# [00:22:21] INFO  | ✅ 环境重置成功
# [00:22:22] INFO  | 开始重置环境...
# [00:22:22] INFO  |   → Initialize... (start_time=7776000s)
# [00:22:23] INFO  |   ✓ Initialize 成功
# [00:22:23] INFO  |   ✓ Set step 成功
# [00:22:23] INFO  |   → Advance...
# [00:22:23] INFO  | ✅ 环境重置成功
# [00:22:25] INFO  | 开始重置环境...
# [00:22:25] INFO  |   → Initialize... (start_time=15552000s)
# [00:22:26] INFO  |   ✓ Initialize 成功
# [00:22:26] INFO  |   ✓ Set step 成功
# [00:22:26] INFO  |   → Advance...
# [00:22:26] INFO  | ✅ 环境重置成功
# [00:22:28] INFO  | 开始重置环境...
# [00:22:28] INFO  |   → Initialize... (start_time=23328000s)
# [00:22:28] INFO  |   ✓ Initialize 成功
# [00:22:28] INFO  |   ✓ Set step 成功
# [00:22:28] INFO  |   → Advance...
# [00:22:28] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -1606.18
# [00:22:30] INFO  | 📊 图表已保存: data/dqn/training_output/training_progress_ep5.png
# [00:22:30] INFO  | 📊 Eval 图已保存: data/dqn/training_output/eval_reward.png
# [00:22:31] INFO  | 📊 Episode 曲线已保存: data/dqn/training_output/curves_ep5.png
#
# ============================================================
# 📊 Episode 6/300
# ============================================================
# [00:22:31] INFO  | 开始重置环境...
# [00:22:31] INFO  |   → Initialize... (start_time=4752000s)
# [00:22:32] INFO  |   ✓ Initialize 成功
# [00:22:32] INFO  |   ✓ Set step 成功
# [00:22:32] INFO  |   → Advance...
# [00:22:32] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 15.5°C | 室外= -1.5°C | R=-50.12 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.959
#            细分: comfort=-50.12, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 18.5°C | 室外= -3.3°C | R= -5.98 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.958
#            细分: comfort=-5.96, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 20.0°C | 室外= -2.3°C | R= +4.96 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A1:0.01] | eps=0.958
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#   Step  40 | 室温= 19.5°C | 室外=  3.2°C | R= -0.75 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.957
#            细分: comfort=-0.75, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 21.0°C | 室外=  7.5°C | R= +4.98 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A9:0.01, A17:0.01] | eps=0.956
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 26.7°C | 室外=  9.2°C | R=-18.02 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A20:0.01] | eps=0.955
#            细分: comfort=-18.01, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 20.8°C | 室外=  7.1°C | R= +4.98 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A9:0.01] | eps=0.954
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 22.6°C | 室外=  1.2°C | R= +4.99 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A20:0.01] | eps=0.953
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 17.3°C | 室外= -3.0°C | R=-17.97 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A6:0.01] | eps=0.953
#            细分: comfort=-17.97, energy=-0.00, smooth=-0.00
#
# ✅ Episode 6 完成 | 总奖励: -912.8 | 平均室温: 20.1°C | 舒适区: 33.3% | 能耗: 63.11 kW
#    Epsilon: 0.952 | Buffer: 576/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 7/300
# ============================================================
# [00:22:34] INFO  | 开始重置环境...
# [00:22:34] INFO  |   → Initialize... (start_time=17107200s)
# [00:22:34] INFO  |   ✓ Initialize 成功
# [00:22:34] INFO  |   ✓ Set step 成功
# [00:22:34] INFO  |   → Advance...
# [00:22:34] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.7°C | 室外= 16.7°C | R=-27.25 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A17:0.01] | eps=0.951
#            细分: comfort=-27.24, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 17.3°C | 室外= 14.9°C | R=-17.98 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A9:0.01] | eps=0.950
#            细分: comfort=-17.98, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 21.4°C | 室外= 20.0°C | R= +4.99 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.950
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.6°C | 室外= 24.2°C | R= +5.00 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.949
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 25.4°C | 室外= 26.6°C | R= -4.69 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A20:0.01] | eps=0.948
#            细分: comfort=-4.69, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 22.2°C | 室外= 28.5°C | R= +4.98 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A13:0.02, A18:0.02] | eps=0.947
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  70 | 室温= 25.2°C | 室外= 27.4°C | R= -3.60 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A20:0.01] | eps=0.946
#            细分: comfort=-3.59, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 20.7°C | 室外= 24.0°C | R= +4.99 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A7:0.01] | eps=0.945
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 23.0°C | 室外= 19.2°C | R= +5.00 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A13:0.01, A18:0.01] | eps=0.945
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 7 完成 | 总奖励: -188.6 | 平均室温: 21.2°C | 舒适区: 51.0% | 能耗: 45.17 kW
#    Epsilon: 0.944 | Buffer: 672/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 8/300
# ============================================================
# [00:22:37] INFO  | 开始重置环境...
# [00:22:37] INFO  |   → Initialize... (start_time=10627200s)
# [00:22:37] INFO  |   ✓ Initialize 成功
# [00:22:37] INFO  |   ✓ Set step 成功
# [00:22:37] INFO  |   → Advance...
# [00:22:37] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.7°C | 室外=  5.2°C | R= +4.97 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A13:0.02, A3:0.01, A6:0.01] | eps=0.943
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 19.7°C | 室外=  4.9°C | R= -0.20 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.942
#            细分: comfort=-0.19, energy=-0.01, smooth=-0.00
#   Step  30 | 室温= 21.3°C | 室外=  9.2°C | R= +4.97 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A16:0.01] | eps=0.942
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  40 | 室温= 23.2°C | 室外= 15.0°C | R= +5.00 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A16:0.01, A13:0.01] | eps=0.941
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 24.5°C | 室外= 20.1°C | R= -0.75 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A16:0.01, A3:0.01] | eps=0.940
#            细分: comfort=-0.74, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 25.6°C | 室外= 23.3°C | R= -6.24 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A13:0.01] | eps=0.939
#            细分: comfort=-6.24, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 20.6°C | 室外= 21.9°C | R= +4.98 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A6:0.01] | eps=0.938
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 20.4°C | 室外= 17.1°C | R= +4.99 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A12:0.01, A3:0.01] | eps=0.937
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 18.4°C | 室外= 13.3°C | R= -6.09 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.937
#            细分: comfort=-6.08, energy=-0.01, smooth=-0.00
#
# ✅ Episode 8 完成 | 总奖励: -282.5 | 平均室温: 20.7°C | 舒适区: 42.7% | 能耗: 52.85 kW
#    Epsilon: 0.936 | Buffer: 768/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 9/300
# ============================================================
# [00:22:39] INFO  | 开始重置环境...
# [00:22:39] INFO  |   → Initialize... (start_time=24105600s)
# [00:22:40] INFO  |   ✓ Initialize 成功
# [00:22:40] INFO  |   ✓ Set step 成功
# [00:22:40] INFO  |   → Advance...
# [00:22:40] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.5°C | 室外= 13.9°C | R=-30.27 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A13:0.01] | eps=0.935
#            细分: comfort=-30.27, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.4°C | 室外= 14.1°C | R=-33.01 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A12:0.01, A18:0.01] | eps=0.934
#            细分: comfort=-33.01, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.8°C | 室外= 14.9°C | R=-25.02 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A6:0.01] | eps=0.934
#            细分: comfort=-25.02, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 23.4°C | 室外= 16.9°C | R= +5.00 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A9:0.01] | eps=0.933
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 20.3°C | 室外= 22.5°C | R= +4.97 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A9:0.02, A18:0.01] | eps=0.932
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 25.9°C | 室外= 16.4°C | R= -8.63 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.931
#            细分: comfort=-8.63, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 24.6°C | 室外= 11.5°C | R= -0.82 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A19:0.01] | eps=0.930
#            细分: comfort=-0.81, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 18.9°C | 室外=  6.8°C | R= -2.94 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A13:0.01] | eps=0.929
#            细分: comfort=-2.94, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 17.5°C | 室外=  5.2°C | R=-15.06 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A17:0.01] | eps=0.929
#            细分: comfort=-15.05, energy=-0.01, smooth=-0.00
#
# ✅ Episode 9 完成 | 总奖励: -425.2 | 平均室温: 20.7°C | 舒适区: 44.8% | 能耗: 50.35 kW
#    Epsilon: 0.928 | Buffer: 864/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 10/300
# ============================================================
# [00:22:42] INFO  | 开始重置环境...
# [00:22:42] INFO  |   → Initialize... (start_time=19699200s)
# [00:22:43] INFO  |   ✓ Initialize 成功
# [00:22:43] INFO  |   ✓ Set step 成功
# [00:22:43] INFO  |   → Advance...
# [00:22:43] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.6°C | 室外= 18.9°C | R=-28.58 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A13:0.01, A3:0.01, A18:0.01] | eps=0.927
#            细分: comfort=-28.58, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 16.9°C | 室外= 19.1°C | R=-24.02 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.926
#            细分: comfort=-24.01, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.9°C | 室外= 22.5°C | R=-24.09 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A12:0.01, A13:0.01] | eps=0.926
#            细分: comfort=-24.09, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 18.9°C | 室外= 30.0°C | R= -2.88 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A13:0.01, A18:0.01] | eps=0.925
#            细分: comfort=-2.87, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 21.5°C | 室外= 31.2°C | R= +4.97 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A16:0.01] | eps=0.924
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 20.7°C | 室外= 29.6°C | R= +4.97 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A16:0.01] | eps=0.923
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 22.9°C | 室外= 26.6°C | R= +4.98 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A20:0.01] | eps=0.922
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 21.5°C | 室外= 21.3°C | R= +4.99 | 动作= 2 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A20:0.01] | eps=0.921
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 23.3°C | 室外= 18.6°C | R= +5.00 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A20:0.01] | eps=0.921
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 10 完成 | 总奖励: -332.2 | 平均室温: 21.2°C | 舒适区: 50.0% | 能耗: 50.90 kW
#    Epsilon: 0.920 | Buffer: 960/12000 | 动作数: 24
# [00:22:45] INFO  | 开始重置环境...
# [00:22:45] INFO  |   → Initialize... (start_time=0s)
# [00:22:46] INFO  |   ✓ Initialize 成功
# [00:22:46] INFO  |   ✓ Set step 成功
# [00:22:46] INFO  |   → Advance...
# [00:22:46] INFO  | ✅ 环境重置成功
# [00:22:48] INFO  | 开始重置环境...
# [00:22:48] INFO  |   → Initialize... (start_time=7776000s)
# [00:22:48] INFO  |   ✓ Initialize 成功
# [00:22:48] INFO  |   ✓ Set step 成功
# [00:22:48] INFO  |   → Advance...
# [00:22:48] INFO  | ✅ 环境重置成功
# [00:22:50] INFO  | 开始重置环境...
# [00:22:50] INFO  |   → Initialize... (start_time=15552000s)
# [00:22:51] INFO  |   ✓ Initialize 成功
# [00:22:51] INFO  |   ✓ Set step 成功
# [00:22:51] INFO  |   → Advance...
# [00:22:51] INFO  | ✅ 环境重置成功
# [00:22:53] INFO  | 开始重置环境...
# [00:22:53] INFO  |   → Initialize... (start_time=23328000s)
# [00:22:53] INFO  |   ✓ Initialize 成功
# [00:22:53] INFO  |   ✓ Set step 成功
# [00:22:53] INFO  |   → Advance...
# [00:22:53] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -1648.31
# [00:22:55] INFO  | 📊 图表已保存: data/dqn/training_output/training_progress_ep10.png
# [00:22:55] INFO  | 📊 Eval 图已保存: data/dqn/training_output/eval_reward.png
# [00:22:56] INFO  | 📊 Episode 曲线已保存: data/dqn/training_output/curves_ep10.png
#
# ============================================================
# 📊 Episode 11/300
# ============================================================
# [00:22:56] INFO  | 开始重置环境...
# [00:22:56] INFO  |   → Initialize... (start_time=22204800s)
# [00:22:57] INFO  |   ✓ Initialize 成功
# [00:22:57] INFO  |   ✓ Set step 成功
# [00:22:57] INFO  |   → Advance...
# [00:22:57] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.5°C | 室外= 13.1°C | R= +4.97 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A19:0.01, A13:0.01] | eps=0.919
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 20.4°C | 室外= 11.8°C | R= +4.98 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A16:0.01] | eps=0.918
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 16.5°C | 室外= 12.1°C | R=-30.42 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A9:0.01] | eps=0.918
#            细分: comfort=-30.42, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 22.9°C | 室外= 14.8°C | R= +5.00 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A16:0.01, A17:0.01] | eps=0.917
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 23.3°C | 室外= 18.0°C | R= +5.00 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A13:0.01, A18:0.01] | eps=0.916
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 23.2°C | 室外= 16.9°C | R= +5.00 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A20:0.01] | eps=0.915
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 19.8°C | 室外= 14.4°C | R= -0.11 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A6:0.01] | eps=0.914
#            细分: comfort=-0.11, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 18.5°C | 室外= 13.0°C | R= -5.66 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A13:0.01, A18:0.01] | eps=0.914
#            细分: comfort=-5.66, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 17.2°C | 室外= 12.3°C | R=-19.10 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A6:0.01] | eps=0.913
#            细分: comfort=-19.10, energy=-0.00, smooth=-0.00
#
# ✅ Episode 11 完成 | 总奖励: -680.9 | 平均室温: 19.4°C | 舒适区: 38.5% | 能耗: 45.55 kW
#    Epsilon: 0.912 | Buffer: 1056/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 12/300
# ============================================================
# [00:22:59] INFO  | 开始重置环境...
# [00:22:59] INFO  |   → Initialize... (start_time=24192000s)
# [00:22:59] INFO  |   ✓ Initialize 成功
# [00:22:59] INFO  |   ✓ Set step 成功
# [00:22:59] INFO  |   → Advance...
# [00:22:59] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.4°C | 室外=  4.6°C | R= +4.97 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A17:0.01] | eps=0.911
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  20 | 室温= 19.6°C | 室外=  4.3°C | R= -0.47 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.911
#            细分: comfort=-0.46, energy=-0.01, smooth=-0.00
#   Step  30 | 室温= 15.6°C | 室外=  3.9°C | R=-48.73 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.910
#            细分: comfort=-48.72, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 20.7°C | 室外=  4.6°C | R= +4.98 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A9:0.01] | eps=0.909
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  50 | 室温= 21.9°C | 室外=  6.4°C | R= +4.99 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.908
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 16.9°C | 室外=  7.9°C | R=-24.42 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A9:0.01] | eps=0.907
#            细分: comfort=-24.42, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 21.8°C | 室外=  6.8°C | R= +4.98 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A16:0.01] | eps=0.906
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 16.1°C | 室外=  4.8°C | R=-38.42 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A13:0.01, A6:0.01] | eps=0.906
#            细分: comfort=-38.42, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 20.6°C | 室外=  3.9°C | R= +4.96 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A20:0.01] | eps=0.905
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#
# ✅ Episode 12 完成 | 总奖励: -1452.2 | 平均室温: 18.5°C | 舒适区: 35.4% | 能耗: 55.46 kW
#    Epsilon: 0.904 | Buffer: 1152/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 13/300
# ============================================================
# [00:23:01] INFO  | 开始重置环境...
# [00:23:01] INFO  |   → Initialize... (start_time=30931200s)
# [00:23:02] INFO  |   ✓ Initialize 成功
# [00:23:02] INFO  |   ✓ Set step 成功
# [00:23:02] INFO  |   → Advance...
# [00:23:02] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 19.3°C | 室外= -2.8°C | R= -1.12 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A13:0.01, A16:0.01] | eps=0.903
#            细分: comfort=-1.10, energy=-0.01, smooth=-0.00
#   Step  20 | 室温= 15.7°C | 室外=  8.6°C | R=-46.54 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A12:0.01] | eps=0.903
#            细分: comfort=-46.54, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 19.6°C | 室外=  7.0°C | R= -0.50 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A6:0.01, A19:0.01] | eps=0.902
#            细分: comfort=-0.48, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 22.7°C | 室外=  7.7°C | R= +5.00 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A13:0.02, A18:0.02] | eps=0.901
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 20.4°C | 室外= 15.1°C | R= +4.97 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A19:0.01] | eps=0.900
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 27.3°C | 室外= 17.9°C | R=-27.11 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A13:0.01, A3:0.01, A18:0.01] | eps=0.899
#            细分: comfort=-27.11, energy=-0.00, smooth=-0.00
#   Step  70 | 室温= 24.7°C | 室外= 11.1°C | R= -1.36 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A13:0.01] | eps=0.898
#            细分: comfort=-1.35, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 23.0°C | 室外=  8.5°C | R= +5.00 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A16:0.01] | eps=0.898
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 22.3°C | 室外=  7.2°C | R= +5.00 | 动作= 5 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A17:0.01, A9:0.01] | eps=0.897
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 13 完成 | 总奖励: -516.3 | 平均室温: 20.8°C | 舒适区: 47.9% | 能耗: 61.55 kW
#    Epsilon: 0.896 | Buffer: 1248/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 14/300
# ============================================================
# [00:23:04] INFO  | 开始重置环境...
# [00:23:04] INFO  |   → Initialize... (start_time=2678400s)
# [00:23:05] INFO  |   ✓ Initialize 成功
# [00:23:05] INFO  |   ✓ Set step 成功
# [00:23:05] INFO  |   → Advance...
# [00:23:05] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 19.8°C | 室外= -5.3°C | R= -0.13 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A19:0.01, A6:0.01] | eps=0.895
#            细分: comfort=-0.11, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 15.2°C | 室外= -6.0°C | R=-58.27 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A13:0.01, A18:0.01] | eps=0.895
#            细分: comfort=-58.27, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 18.7°C | 室外= -7.6°C | R= -4.26 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A6:0.01, A13:0.01, A3:0.01] | eps=0.894
#            细分: comfort=-4.24, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 22.5°C | 室外=  0.5°C | R= +5.00 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A12:0.01, A3:0.01] | eps=0.893
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 21.4°C | 室外=  7.0°C | R= +4.97 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A13:0.01, A3:0.01] | eps=0.892
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 22.5°C | 室外=  9.3°C | R= +4.97 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A9:0.01, A3:0.01] | eps=0.891
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 24.5°C | 室外=  5.9°C | R= -0.55 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A12:0.01] | eps=0.890
#            细分: comfort=-0.54, energy=-0.00, smooth=-0.00
#   Step  80 | 室温= 19.9°C | 室外= -2.1°C | R= -0.03 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A20:0.01] | eps=0.890
#            细分: comfort=-0.03, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 18.4°C | 室外= -3.7°C | R= -6.14 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A17:0.01] | eps=0.889
#            细分: comfort=-6.13, energy=-0.00, smooth=-0.00
#
# ✅ Episode 14 完成 | 总奖励: -540.2 | 平均室温: 20.7°C | 舒适区: 45.8% | 能耗: 69.48 kW
#    Epsilon: 0.888 | Buffer: 1344/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 15/300
# ============================================================
# [00:23:07] INFO  | 开始重置环境...
# [00:23:07] INFO  |   → Initialize... (start_time=24710400s)
# [00:23:08] INFO  |   ✓ Initialize 成功
# [00:23:08] INFO  |   ✓ Set step 成功
# [00:23:08] INFO  |   → Advance...
# [00:23:08] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.7°C | 室外=  5.8°C | R=-27.94 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A16:0.02, A18:0.01, A9:0.01] | eps=0.887
#            细分: comfort=-27.93, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 20.8°C | 室外=  3.8°C | R= +4.96 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A9:0.01, A6:0.01] | eps=0.887
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#   Step  30 | 室温= 20.9°C | 室外=  3.5°C | R= +4.96 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A19:0.01] | eps=0.886
#            细分: comfort=+5.00, energy=-0.04, smooth=-0.00
#   Step  40 | 室温= 20.4°C | 室外= 13.3°C | R= +4.99 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A1:0.01, A13:0.01] | eps=0.885
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.9°C | 室外= 17.5°C | R= -8.62 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A13:0.01] | eps=0.884
#            细分: comfort=-8.61, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 26.1°C | 室外= 19.6°C | R=-11.12 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A9:0.01] | eps=0.883
#            细分: comfort=-11.11, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 23.9°C | 室外= 19.6°C | R= +4.98 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A20:0.01] | eps=0.882
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 21.3°C | 室外= 10.0°C | R= +4.99 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.882
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 22.8°C | 室外=  5.9°C | R= +4.99 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A9:0.01] | eps=0.881
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 15 完成 | 总奖励: -496.2 | 平均室温: 21.4°C | 舒适区: 42.7% | 能耗: 62.45 kW
#    Epsilon: 0.880 | Buffer: 1440/12000 | 动作数: 21
# [00:23:10] INFO  | 开始重置环境...
# [00:23:10] INFO  |   → Initialize... (start_time=0s)
# [00:23:11] INFO  |   ✓ Initialize 成功
# [00:23:11] INFO  |   ✓ Set step 成功
# [00:23:11] INFO  |   → Advance...
# [00:23:11] INFO  | ✅ 环境重置成功
# [00:23:12] INFO  | 开始重置环境...
# [00:23:12] INFO  |   → Initialize... (start_time=7776000s)
# [00:23:13] INFO  |   ✓ Initialize 成功
# [00:23:13] INFO  |   ✓ Set step 成功
# [00:23:13] INFO  |   → Advance...
# [00:23:13] INFO  | ✅ 环境重置成功
# [00:23:15] INFO  | 开始重置环境...
# [00:23:15] INFO  |   → Initialize... (start_time=15552000s)
# [00:23:16] INFO  |   ✓ Initialize 成功
# [00:23:16] INFO  |   ✓ Set step 成功
# [00:23:16] INFO  |   → Advance...
# [00:23:16] INFO  | ✅ 环境重置成功
# [00:23:17] INFO  | 开始重置环境...
# [00:23:17] INFO  |   → Initialize... (start_time=23328000s)
# [00:23:18] INFO  |   ✓ Initialize 成功
# [00:23:18] INFO  |   ✓ Set step 成功
# [00:23:18] INFO  |   → Advance...
# [00:23:18] INFO  | ✅ 环境重置成功
#   🔍 Eval avg reward: -1585.38
# [00:23:20] INFO  | 📊 图表已保存: data/dqn/training_output/training_progress_ep15.png
# [00:23:20] INFO  | 📊 Eval 图已保存: data/dqn/training_output/eval_reward.png
# [00:23:20] INFO  | 📊 Episode 曲线已保存: data/dqn/training_output/curves_ep15.png
#
# ============================================================
# 📊 Episode 16/300
# ============================================================
# [00:23:20] INFO  | 开始重置环境...
# [00:23:20] INFO  |   → Initialize... (start_time=9936000s)
# [00:23:21] INFO  |   ✓ Initialize 成功
# [00:23:21] INFO  |   ✓ Set step 成功
# [00:23:21] INFO  |   → Advance...
# [00:23:21] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 20.6°C | 室外= 11.9°C | R= +4.98 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A19:0.01] | eps=0.879
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 16.1°C | 室外= 11.2°C | R=-37.35 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A17:0.01] | eps=0.879
#            细分: comfort=-37.34, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 21.0°C | 室外= 15.9°C | R= +4.99 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A16:0.01, A6:0.01] | eps=0.878
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.7°C | 室外= 21.3°C | R= +5.00 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A17:0.01] | eps=0.877
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 22.5°C | 室外= 24.4°C | R= +4.98 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.876
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  60 | 室温= 20.2°C | 室外= 25.5°C | R= +4.97 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A13:0.01, A18:0.01, A3:0.01] | eps=0.875
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 21.0°C | 室外= 24.2°C | R= +4.98 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A19:0.01, A6:0.01] | eps=0.874
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 23.5°C | 室外= 20.5°C | R= +5.00 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A9:0.01, A3:0.01] | eps=0.874
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 22.9°C | 室外= 13.3°C | R= +5.00 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A19:0.01] | eps=0.873
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 16 完成 | 总奖励: -291.8 | 平均室温: 21.0°C | 舒适区: 56.2% | 能耗: 51.00 kW
#    Epsilon: 0.872 | Buffer: 1536/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 17/300
# ============================================================
# [00:23:23] INFO  | 开始重置环境...
# [00:23:23] INFO  |   → Initialize... (start_time=20995200s)
# [00:23:24] INFO  |   ✓ Initialize 成功
# [00:23:24] INFO  |   ✓ Set step 成功
# [00:23:24] INFO  |   → Advance...
# [00:23:24] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.9°C | 室外= 19.2°C | R= +4.98 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A7:0.01] | eps=0.871
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 16.9°C | 室外= 18.4°C | R=-23.48 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A6:0.01] | eps=0.871
#            细分: comfort=-23.48, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.7°C | 室外= 18.9°C | R=-27.29 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.870
#            细分: comfort=-27.28, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 19.7°C | 室外= 25.4°C | R= -0.19 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A16:0.01] | eps=0.869
#            细分: comfort=-0.18, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 25.4°C | 室外= 29.8°C | R= -5.12 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A19:0.01] | eps=0.868
#            细分: comfort=-5.12, energy=-0.00, smooth=-0.00
#   Step  60 | 室温= 21.0°C | 室外= 29.1°C | R= +4.97 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A20:0.01] | eps=0.867
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 25.6°C | 室外= 31.5°C | R= -6.33 | 动作=14 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.01, A6:0.01, A13:0.01] | eps=0.866
#            细分: comfort=-6.33, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 24.8°C | 室外= 25.8°C | R= -1.65 | 动作= 4 | Fan=0.4|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A20:0.01] | eps=0.866
#            细分: comfort=-1.65, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 23.8°C | 室外= 23.1°C | R= +4.99 | 动作=20 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A9:0.01] | eps=0.865
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#
# ✅ Episode 17 完成 | 总奖励: -220.6 | 平均室温: 21.6°C | 舒适区: 45.8% | 能耗: 53.51 kW
#    Epsilon: 0.864 | Buffer: 1632/12000 | 动作数: 23
#
# ============================================================
# 📊 Episode 18/300
# ============================================================
# [00:23:26] INFO  | 开始重置环境...
# [00:23:26] INFO  |   → Initialize... (start_time=26697600s)
# [00:23:27] INFO  |   ✓ Initialize 成功
# [00:23:27] INFO  |   ✓ Set step 成功
# [00:23:27] INFO  |   → Advance...
# [00:23:27] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.3°C | 室外=  3.9°C | R=-34.73 | 动作= 8 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A16:0.01] | eps=0.863
#            细分: comfort=-34.72, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.1°C | 室外=  4.2°C | R=-38.45 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A13:0.01] | eps=0.863
#            细分: comfort=-38.45, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 15.8°C | 室外=  5.7°C | R=-44.41 | 动作=10 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A13:0.01] | eps=0.862
#            细分: comfort=-44.41, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 18.1°C | 室外= 11.6°C | R= -8.70 | 动作=16 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A6:0.01, A9:0.01] | eps=0.861
#            细分: comfort=-8.69, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 20.5°C | 室外= 18.5°C | R= +4.97 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A17:0.01, A13:0.01] | eps=0.860
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  60 | 室温= 22.4°C | 室外= 18.7°C | R= +4.97 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A16:0.01] | eps=0.859
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 21.3°C | 室外= 12.7°C | R= +4.98 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A16:0.01] | eps=0.858
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 23.4°C | 室外= 10.1°C | R= +5.00 | 动作=12 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A13:0.01, A18:0.01] | eps=0.858
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 18.4°C | 室外=  7.5°C | R= -6.60 | 动作=11 | Fan=0.7|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A12:0.01, A18:0.01] | eps=0.857
#            细分: comfort=-6.59, energy=-0.01, smooth=-0.00
#
# ✅ Episode 18 完成 | 总奖励: -560.3 | 平均室温: 20.6°C | 舒适区: 53.1% | 能耗: 60.92 kW
#    Epsilon: 0.856 | Buffer: 1728/12000 | 动作数: 24
#
# ============================================================
# 📊 Episode 19/300
# ============================================================
# [00:23:29] INFO  | 开始重置环境...
# [00:23:29] INFO  |   → Initialize... (start_time=18748800s)
# [00:23:30] INFO  |   ✓ Initialize 成功
# [00:23:30] INFO  |   ✓ Set step 成功
# [00:23:30] INFO  |   → Advance...
# [00:23:30] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 17.5°C | 室外= 17.7°C | R=-15.33 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A13:0.01] | eps=0.855
#            细分: comfort=-15.33, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 17.3°C | 室外= 15.8°C | R=-18.16 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A9:0.01] | eps=0.855
#            细分: comfort=-18.16, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.9°C | 室外= 22.7°C | R=-24.13 | 动作=17 | Fan=1.0|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.854
#            细分: comfort=-24.13, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.8°C | 室外= 27.9°C | R= +4.99 | 动作=21 | Fan=1.0|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A13:0.01] | eps=0.853
# ...
#   Step  20 | 室温= 19.3°C | 室外= -5.4°C | R= -1.18 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.02, A12:0.01] | eps=0.431
#            细分: comfort=-1.16, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 18.2°C | 室外= -2.4°C | R= -7.87 | 动作= 7 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A7:0.01] | eps=0.430
#            细分: comfort=-7.85, energy=-0.02, smooth=-0.00
#   Step  40 | 室温= 17.8°C | 室外=  1.6°C | R=-12.32 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A8:0.01, A3:0.01, A13:0.01] | eps=0.429
#            细分: comfort=-12.31, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 18.3°C | 室外=  4.3°C | R= -7.56 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.02, A13:0.01] | eps=0.428
#            细分: comfort=-7.55, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 18.6°C | 室外=  5.1°C | R= -4.69 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.428
#            细分: comfort=-4.68, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 18.1°C | 室外=  6.2°C | R= -8.94 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A9:0.01, A1:0.01] | eps=0.427
#            细分: comfort=-8.93, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 17.5°C | 室外=  3.6°C | R=-15.24 | 动作= 1 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A17:0.01] | eps=0.426
#            细分: comfort=-15.24, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 16.6°C | 室外=  1.5°C | R=-28.56 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.425
#            细分: comfort=-28.56, energy=-0.00, smooth=-0.00
#
# ✅ Episode 72 完成 | 总奖励: -1599.6 | 平均室温: 18.4°C | 舒适区: 26.0% | 能耗: 54.23 kW
#    Epsilon: 0.425 | Buffer: 6912/12000 | 动作数: 19
#
# ============================================================
# 📊 Episode 73/300
# ============================================================
# [00:29:55] INFO  | 开始重置环境...
# [00:29:55] INFO  |   → Initialize... (start_time=11232000s)
# [00:29:56] INFO  |   ✓ Initialize 成功
# [00:29:56] INFO  |   ✓ Set step 成功
# [00:29:56] INFO  |   → Advance...
# [00:29:56] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 16.1°C | 室外=  6.7°C | R=-38.99 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A13:0.02, A3:0.02, A18:0.01] | eps=0.424
#            细分: comfort=-38.99, energy=-0.00, smooth=-0.00
#   Step  20 | 室温= 16.1°C | 室外=  6.7°C | R=-38.53 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A16:0.01] | eps=0.423
#            细分: comfort=-38.52, energy=-0.00, smooth=-0.00
#   Step  30 | 室温= 16.1°C | 室外=  6.7°C | R=-38.50 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A20:0.01] | eps=0.422
#            细分: comfort=-38.49, energy=-0.00, smooth=-0.00
#   Step  40 | 室温= 17.6°C | 室外=  8.1°C | R=-14.96 | 动作= 3 | Fan=0.4|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A18:0.01, A3:0.01, A16:0.01] | eps=0.421
#            细分: comfort=-14.96, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 17.3°C | 室外= 10.7°C | R=-18.45 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.01, A18:0.01, A13:0.01] | eps=0.420
#            细分: comfort=-18.44, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 18.0°C | 室外= 12.8°C | R= -9.84 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A18:0.01, A13:0.01] | eps=0.420
#            细分: comfort=-9.83, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 17.4°C | 室外= 11.9°C | R=-17.52 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A18:0.02, A3:0.01, A13:0.01] | eps=0.419
#            细分: comfort=-17.51, energy=-0.01, smooth=-0.00
#   Step  80 | 室温= 16.3°C | 室外=  9.1°C | R=-34.69 | 动作=19 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A3:0.02, A17:0.01, A13:0.01] | eps=0.418
#            细分: comfort=-34.69, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 20.6°C | 室外=  8.3°C | R= +4.97 | 动作=13 | Fan=0.7|供风=23°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A23:0.06, A13:0.05, A14:0.05] | eps=0.417
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#
# ✅ Episode 73 完成 | 总奖励: -1749.5 | 平均室温: 17.9°C | 舒适区: 17.7% | 能耗: 40.04 kW
#    Epsilon: 0.417 | Buffer: 7008/12000 | 动作数: 18
#
# ============================================================
# 📊 Episode 74/300
# ============================================================
# [00:30:00] INFO  | 开始重置环境...
# [00:30:00] INFO  |   → Initialize... (start_time=17107200s)
# [00:30:01] INFO  |   ✓ Initialize 成功
# [00:30:01] INFO  |   ✓ Set step 成功
# [00:30:01] INFO  |   → Advance...
# [00:30:01] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 21.9°C | 室外= 16.7°C | R= +4.98 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:0.41, A13:0.37, A21:0.37] | eps=0.416
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 21.8°C | 室外= 14.9°C | R= +4.98 | 动作=22 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A23:0.76, A22:0.69, A21:0.69] | eps=0.415
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 17.6°C | 室外= 20.0°C | R=-14.02 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A23:1.09, A22:1.00, A20:0.99] | eps=0.414
#            细分: comfort=-14.01, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 23.8°C | 室外= 24.2°C | R= +4.99 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:1.45, A20:1.33, A21:1.30] | eps=0.413
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  50 | 室温= 24.6°C | 室外= 26.6°C | R= -1.00 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:1.79, A20:1.65, A21:1.53] | eps=0.413
#            细分: comfort=-1.00, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 20.4°C | 室外= 28.5°C | R= +4.97 | 动作=18 | Fan=1.0|供风=15°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A23:2.12, A20:1.92, A22:1.80] | eps=0.412
#            细分: comfort=+5.00, energy=-0.03, smooth=-0.00
#   Step  70 | 室温= 21.2°C | 室外= 27.4°C | R= +4.98 | 动作= 9 | Fan=0.7|供风=15°C|热设=21.0°C|冷设=28.0°C
#            Top3 Q: [A23:2.44, A20:2.10, A22:2.05] | eps=0.411
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 23.7°C | 室外= 24.0°C | R= +4.99 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:2.73, A20:2.25, A22:2.25] | eps=0.410
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  90 | 室温= 23.4°C | 室外= 19.2°C | R= +5.00 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:3.00, A22:2.42, A20:2.41] | eps=0.409
#            细分: comfort=+5.00, energy=-0.00, smooth=-0.00
#
# ✅ Episode 74 完成 | 总奖励: 151.7 | 平均室温: 22.6°C | 舒适区: 62.5% | 能耗: 49.47 kW
#    Epsilon: 0.409 | Buffer: 7104/12000 | 动作数: 22
#
# ============================================================
# 📊 Episode 75/300
# ============================================================
# [00:30:07] INFO  | 开始重置环境...
# [00:30:07] INFO  |   → Initialize... (start_time=15638400s)
# [00:30:08] INFO  |   ✓ Initialize 成功
# [00:30:08] INFO  |   ✓ Set step 成功
# [00:30:08] INFO  |   → Advance...
# [00:30:08] INFO  | ✅ 环境重置成功
#   Step  10 | 室温= 22.1°C | 室外= 18.5°C | R= +4.98 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:3.30, A22:2.60, A20:2.58] | eps=0.408
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  20 | 室温= 21.9°C | 室外= 16.5°C | R= +4.98 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:3.51, A22:2.68, A20:2.67] | eps=0.407
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  30 | 室温= 21.8°C | 室外= 20.9°C | R= +4.99 | 动作= 6 | Fan=0.4|供风=23°C|热设=23.0°C|冷设=26.0°C
#            Top3 Q: [A23:3.69, A22:2.75, A20:2.72] | eps=0.406
#            细分: comfort=+5.00, energy=-0.01, smooth=-0.00
#   Step  40 | 室温= 24.4°C | 室外= 28.4°C | R= -0.34 | 动作=15 | Fan=0.7|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:3.84, A22:2.87, A21:2.86] | eps=0.405
#            细分: comfort=-0.34, energy=-0.00, smooth=-0.00
#   Step  50 | 室温= 25.1°C | 室外= 33.1°C | R= -2.95 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:3.97, A21:3.02, A22:2.98] | eps=0.405
#            细分: comfort=-2.94, energy=-0.01, smooth=-0.00
#   Step  60 | 室温= 25.4°C | 室外= 34.3°C | R= -4.84 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:4.05, A21:3.16, A22:3.04] | eps=0.404
#            细分: comfort=-4.83, energy=-0.01, smooth=-0.00
#   Step  70 | 室温= 23.8°C | 室外= 34.1°C | R= +4.98 | 动作= 0 | Fan=0.4|供风=15°C|热设=21.0°C|冷设=26.0°C
#            Top3 Q: [A23:4.08, A21:3.18, A22:3.14] | eps=0.403
#            细分: comfort=+5.00, energy=-0.02, smooth=-0.00
#   Step  80 | 室温= 24.4°C | 室外= 28.8°C | R= -0.42 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:4.08, A20:3.25, A22:3.22] | eps=0.402
#            细分: comfort=-0.41, energy=-0.00, smooth=-0.00
#   Step  90 | 室温= 24.1°C | 室外= 24.7°C | R= -0.01 | 动作=23 | Fan=1.0|供风=23°C|热设=23.0°C|冷设=28.0°C
#            Top3 Q: [A23:4.05, A20:3.39, A21:3.30] | eps=0.401
#            细分: comfort=-0.01, energy=-0.00, smooth=-0.00
#
# ✅ Episode 75 完成 | 总奖励: 21.7 | 平均室温: 23.3°C | 舒适区: 44.8% | 能耗: 50.42 kW
#    Epsilon: 0.401 | Buffer: 7200/12000 | 动作数: 20
# [00:30:13] INFO  | 开始重置环境...
# [00:30:13] INFO  |   → Initialize... (start_time=0s)
# [00:30:14] INFO  |   ✓ Initialize 成功
# [00:30:14] INFO  |   ✓ Set step 成功
# [00:30:14] INFO  |   → Advance...
# [00:30:14] INFO  | ✅ 环境重置成功
# [00:30:15] INFO  | 开始重置环境...
# [00:30:15] INFO  |   → Initialize... (start_time=7776000s)
# [00:30:16] INFO  |   ✓ Initialize 成功
# [00:30:16] INFO  |   ✓ Set step 成功
# [00:30:16] INFO  |   → Advance...
# [00:30:16] INFO  | ✅ 环境重置成功
# [00:30:17] INFO  | 开始重置环境...
# [00:30:17] INFO  |   → Initialize... (start_time=15552000s)
# [00:30:18] INFO  |   ✓ Initialize 成功
# [00:30:18] INFO  |   ✓ Set step 成功
# [00:30:18] INFO  |   → Advance...
# [00:30:18] INFO  | ✅ 环境重置成功
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/BOPTEST_Benchmark/methods/dqn/train.py:230
#     226     log("DQN 训练结束")
#     229 if __name__ == "__main__":
# --> 230     train()
#
# File ~/Desktop/BOPTEST_Benchmark/methods/dqn/train.py:208, in train()
#     206 with torch.no_grad():
#     207     a = q_net(torch.FloatTensor(s).unsqueeze(0)).argmax(dim=1).item()
# --> 208 s, r, d, _ = env.step(a)
#     209 er += r
#     210 if d:
#
# File ~/Desktop/BOPTEST_Benchmark/env.py:103, in BOPTESTEnv.step(self, action_idx)
#      96 v = action_to_values(action_idx, config.__dict__)
#      97 control = {
#      98     "fcu_oveFan_u": v["fan"], "fcu_oveFan_activate": 1,
#      99     "fcu_oveTSup_u": v["supply_temp"], "fcu_oveTSup_activate": 1,
#     100     "con_oveTSetHea_u": v["heat_setpoint"], "con_oveTSetHea_activate": 1,
#     101     "con_oveTSetCoo_u": v["cool_setpoint"], "con_oveTSetCoo_activate": 1,
#     102 }
# --> 103 resp = requests.post(f"{self.url}/advance/{self.testid}", json=control, timeout=60)
#     104 payload = resp.json().get("payload", {}) or {}
#     105 obs = self._get_obs(payload)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
