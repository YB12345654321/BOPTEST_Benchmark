# %% [markdown]
# ## 五方法对比
#
# 在 Jupyter 中运行对比脚本（与 `python compare_runs.py` 等价）。会读取各方法 `data/<method>/` 下的训练数据，生成对比图与汇总表。
#
# **使用前：** 至少跑过一种方法的训练；建议五方法都跑完后运行。
#
# **使用前请：** 在 BOPTEST_Benchmark 根目录下启动 Jupyter，再打开本 notebook。

# %%
import os
import sys

ROOT = os.getcwd()
if not os.path.isfile(os.path.join(ROOT, "compare_runs.py")):
    print("当前目录:", ROOT)
    raise SystemError("请在 BOPTEST_Benchmark 根目录下启动 Jupyter")

sys.path.insert(0, ROOT)
os.chdir(ROOT)
print("项目根目录:", ROOT)

# %%
# %run compare_runs.py
